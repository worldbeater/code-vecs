# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import RandomForestClassifier
from utilities import read_dataset_folder, describe, statistics

import random
import numpy as np
import ast
import dis
import types

def instructions(co):
    bytecode = dis.Bytecode(co)
    iset = []
    for instr in bytecode:
        iset.append(instr.opname)
        if isinstance(instr.argval, types.CodeType):
            iset += instructions(instr.argval)
    return iset

def vectorize(codes):
    isets = []
    for code in codes:
        tree = ast.parse(code)
        co = compile(tree, '', 'exec')
        iset = instructions(co)
        isets.append(iset)
    ops = set(i for iset in isets for i in iset)
    print(f'Dim (opcode count): {len(ops)}')
    vecs = []
    for iset in isets:
        total = len(iset)
        vec = []
        for op in ops:
            this = len([i for i in iset if i == op])
            vec.append(this / total)
        vecs.append(vec)
    return vecs

def dataset(folder='data', count=2000):
    random.seed(42)
    programs = random.sample(read_dataset_folder(folder), count)
    print(f'Total programs: {len(programs)}')
    vectors = vectorize([code for code, _ in programs])
    x = np.array(list(vectors), dtype=np.float32)
    y = np.array([klass for _, klass in programs], dtype=int).reshape((len(programs), 1))
    return None, x, y

describe(dataset)
# Out:
# Total programs: 100
# Dim (opcode count): 73
# Components: 73.
# Non-zero components: 15.
# Zero components: 58.

# %% [markdown]
# **Plots 100-1000**

# %%
stats = statistics(dataset, KNeighborsClassifier, {
    'n_neighbors': [4],
    'weights': ('distance',),
    'metric': ('manhattan',)
}, 100, 1000 + 100, 100)
# Out:
# Total programs: 100
# Dim (opcode count): 73
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.3s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
#
# {'metric': 'manhattan', 'n_neighbors': 4, 'weights': 'distance'}
# {'accuracy': (0.84, 0.107),
#  'f1_macro': (0.783, 0.127),
#  'f1_weighted': (0.821, 0.111),
#  'fit_time': (0.001, 0.0),
#  'precision_macro': (0.787, 0.125),
#  'precision_weighted': (0.828, 0.107),
#  'recall_macro': (0.803, 0.121),
#  'recall_weighted': (0.84, 0.107),
#  'score_time': (0.098, 0.154)}
# Total programs: 200
# Dim (opcode count): 82
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
#
# {'metric': 'manhattan', 'n_neighbors': 4, 'weights': 'distance'}
# {'accuracy': (0.935, 0.025),
#  'f1_macro': (0.927, 0.024),
#  'f1_weighted': (0.933, 0.026),
#  'fit_time': (0.001, 0.0),
#  'precision_macro': (0.953, 0.017),
#  'precision_weighted': (0.95, 0.02),
#  'recall_macro': (0.924, 0.025),
#  'recall_weighted': (0.935, 0.025),
#  'score_time': (0.022, 0.001)}
# Total programs: 300
# Dim (opcode count): 84
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
#
# {'metric': 'manhattan', 'n_neighbors': 4, 'weights': 'distance'}
# {'accuracy': (0.937, 0.022),
#  'f1_macro': (0.931, 0.026),
#  'f1_weighted': (0.936, 0.022),
#  'fit_time': (0.001, 0.0),
#  'precision_macro': (0.95, 0.017),
#  'precision_weighted': (0.95, 0.015),
#  'recall_macro': (0.929, 0.028),
#  'recall_weighted': (0.937, 0.022),
#  'score_time': (0.022, 0.001)}
# Total programs: 400
# Dim (opcode count): 86
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
#
# {'metric': 'manhattan', 'n_neighbors': 4, 'weights': 'distance'}
# {'accuracy': (0.94, 0.04),
#  'f1_macro': (0.936, 0.045),
#  'f1_weighted': (0.941, 0.038),
#  'fit_time': (0.001, 0.0),
#  'precision_macro': (0.948, 0.035),
#  'precision_weighted': (0.952, 0.026),
#  'recall_macro': (0.936, 0.044),
#  'recall_weighted': (0.94, 0.04),
#  'score_time': (0.024, 0.002)}
# Total programs: 500
# Dim (opcode count): 86
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
#
# {'metric': 'manhattan', 'n_neighbors': 4, 'weights': 'distance'}
# {'accuracy': (0.956, 0.023),
#  'f1_macro': (0.952, 0.025),
#  'f1_weighted': (0.956, 0.023),
#  'fit_time': (0.001, 0.0),
#  'precision_macro': (0.963, 0.017),
#  'precision_weighted': (0.964, 0.014),
#  'recall_macro': (0.95, 0.024),
#  'recall_weighted': (0.956, 0.023),
#  'score_time': (0.025, 0.001)}
# Total programs: 600
# Dim (opcode count): 89
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
#
# {'metric': 'manhattan', 'n_neighbors': 4, 'weights': 'distance'}
# {'accuracy': (0.963, 0.014),
#  'f1_macro': (0.962, 0.014),
#  'f1_weighted': (0.964, 0.013),
#  'fit_time': (0.001, 0.001),
#  'precision_macro': (0.967, 0.011),
#  'precision_weighted': (0.968, 0.01),
#  'recall_macro': (0.961, 0.015),
#  'recall_weighted': (0.963, 0.014),
#  'score_time': (0.025, 0.001)}
# Total programs: 700
# Dim (opcode count): 89
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
#
# {'metric': 'manhattan', 'n_neighbors': 4, 'weights': 'distance'}
# {'accuracy': (0.954, 0.02),
#  'f1_macro': (0.954, 0.021),
#  'f1_weighted': (0.954, 0.02),
#  'fit_time': (0.001, 0.0),
#  'precision_macro': (0.956, 0.021),
#  'precision_weighted': (0.957, 0.019),
#  'recall_macro': (0.955, 0.02),
#  'recall_weighted': (0.954, 0.02),
#  'score_time': (0.027, 0.002)}
# Total programs: 800
# Dim (opcode count): 89
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
#
# {'metric': 'manhattan', 'n_neighbors': 4, 'weights': 'distance'}
# {'accuracy': (0.96, 0.019),
#  'f1_macro': (0.959, 0.018),
#  'f1_weighted': (0.96, 0.019),
#  'fit_time': (0.001, 0.0),
#  'precision_macro': (0.963, 0.017),
#  'precision_weighted': (0.964, 0.017),
#  'recall_macro': (0.959, 0.018),
#  'recall_weighted': (0.96, 0.019),
#  'score_time': (0.03, 0.005)}
# Total programs: 900
# Dim (opcode count): 91
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
#
# {'metric': 'manhattan', 'n_neighbors': 4, 'weights': 'distance'}
# {'accuracy': (0.96, 0.002),
#  'f1_macro': (0.96, 0.003),
#  'f1_weighted': (0.96, 0.002),
#  'fit_time': (0.001, 0.0),
#  'precision_macro': (0.962, 0.004),
#  'precision_weighted': (0.963, 0.003),
#  'recall_macro': (0.96, 0.003),
#  'recall_weighted': (0.96, 0.002),
#  'score_time': (0.027, 0.001)}
# Total programs: 1000
# Dim (opcode count): 91
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
#
# {'metric': 'manhattan', 'n_neighbors': 4, 'weights': 'distance'}
# {'accuracy': (0.961, 0.009),
#  'f1_macro': (0.961, 0.009),
#  'f1_weighted': (0.961, 0.009),
#  'fit_time': (0.001, 0.0),
#  'precision_macro': (0.963, 0.009),
#  'precision_weighted': (0.963, 0.009),
#  'recall_macro': (0.961, 0.009),
#  'recall_weighted': (0.961, 0.009),
#  'score_time': (0.03, 0.001)}
# [{'accuracy': (0.84, 0.107), 'f1_macro': (0.783, 0.127), 'fit_time': (0.001, 0.0), 'precision_macro': (0.787, 0.125), 'recall_macro': (0.803, 0.121), 'score_time': (0.098, 0.154)},
#  {'accuracy': (0.935, 0.025), 'f1_macro': (0.927, 0.024), 'fit_time': (0.001, 0.0), 'precision_macro': (0.953, 0.017), 'recall_macro': (0.924, 0.025), 'score_time': (0.022, 0.001)},
#  {'accuracy': (0.937, 0.022), 'f1_macro': (0.931, 0.026), 'fit_time': (0.001, 0.0), 'precision_macro': (0.95, 0.017), 'recall_macro': (0.929, 0.028), 'score_time': (0.022, 0.001)},
#  {'accuracy': (0.94, 0.04), 'f1_macro': (0.936, 0.045), 'fit_time': (0.001, 0.0), 'precision_macro': (0.948, 0.035), 'recall_macro': (0.936, 0.044), 'score_time': (0.024, 0.002)},
#  {'accuracy': (0.956, 0.023), 'f1_macro': (0.952, 0.025), 'fit_time': (0.001, 0.0), 'precision_macro': (0.963, 0.017), 'recall_macro': (0.95, 0.024), 'score_time': (0.025, 0.001)},
#  {'accuracy': (0.963, 0.014), 'f1_macro': (0.962, 0.014), 'fit_time': (0.001, 0.001), 'precision_macro': (0.967, 0.011), 'recall_macro': (0.961, 0.015), 'score_time': (0.025, 0.001)},
#  {'accuracy': (0.954, 0.02), 'f1_macro': (0.954, 0.021), 'fit_time': (0.001, 0.0), 'precision_macro': (0.956, 0.021), 'recall_macro': (0.955, 0.02), 'score_time': (0.027, 0.002)},
#  {'accuracy': (0.96, 0.019), 'f1_macro': (0.959, 0.018), 'fit_time': (0.001, 0.0), 'precision_macro': (0.963, 0.017), 'recall_macro': (0.959, 0.018), 'score_time': (0.03, 0.005)},
#  {'accuracy': (0.96, 0.002), 'f1_macro': (0.96, 0.003), 'fit_time': (0.001, 0.0), 'precision_macro': (0.962, 0.004), 'recall_macro': (0.96, 0.003), 'score_time': (0.027, 0.001)},
#  {'accuracy': (0.961, 0.009), 'f1_macro': (0.961, 0.009), 'fit_time': (0.001, 0.0), 'precision_macro': (0.963, 0.009), 'recall_macro': (0.961, 0.009), 'score_time': (0.03, 0.001)}]

# %%
stats = statistics(dataset, SVC, {
    'C': [30],
    'kernel': ('rbf',),
}, 100, 1000 + 100, 100)
# Out:
# Total programs: 100
# Dim (opcode count): 73
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
#
# {'C': 30, 'kernel': 'rbf'}
# {'accuracy': (0.87, 0.093),
#  'f1_macro': (0.836, 0.113),
#  'f1_weighted': (0.856, 0.101),
#  'fit_time': (0.002, 0.0),
#  'precision_macro': (0.836, 0.116),
#  'precision_weighted': (0.857, 0.103),
#  'recall_macro': (0.848, 0.103),
#  'recall_weighted': (0.87, 0.093),
#  'score_time': (0.01, 0.006)}
# Total programs: 200
# Dim (opcode count): 82
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
#
# {'C': 30, 'kernel': 'rbf'}
# {'accuracy': (0.92, 0.043),
#  'f1_macro': (0.909, 0.057),
#  'f1_weighted': (0.915, 0.048),
#  'fit_time': (0.003, 0.0),
#  'precision_macro': (0.921, 0.061),
#  'precision_weighted': (0.925, 0.048),
#  'recall_macro': (0.912, 0.051),
#  'recall_weighted': (0.92, 0.043),
#  'score_time': (0.007, 0.0)}
# Total programs: 300
# Dim (opcode count): 84
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
#
# {'C': 30, 'kernel': 'rbf'}
# {'accuracy': (0.933, 0.03),
#  'f1_macro': (0.926, 0.032),
#  'f1_weighted': (0.934, 0.029),
#  'fit_time': (0.004, 0.0),
#  'precision_macro': (0.937, 0.03),
#  'precision_weighted': (0.942, 0.027),
#  'recall_macro': (0.925, 0.034),
#  'recall_weighted': (0.933, 0.03),
#  'score_time': (0.008, 0.0)}
# Total programs: 400
# Dim (opcode count): 86
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
#
# {'C': 30, 'kernel': 'rbf'}
# {'accuracy': (0.943, 0.037),
#  'f1_macro': (0.939, 0.039),
#  'f1_weighted': (0.942, 0.037),
#  'fit_time': (0.006, 0.0),
#  'precision_macro': (0.95, 0.037),
#  'precision_weighted': (0.951, 0.031),
#  'recall_macro': (0.938, 0.036),
#  'recall_weighted': (0.943, 0.037),
#  'score_time': (0.009, 0.0)}
# Total programs: 500
# Dim (opcode count): 86
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
#
# {'C': 30, 'kernel': 'rbf'}
# {'accuracy': (0.96, 0.013),
#  'f1_macro': (0.956, 0.013),
#  'f1_weighted': (0.96, 0.013),
#  'fit_time': (0.007, 0.001),
#  'precision_macro': (0.962, 0.011),
#  'precision_weighted': (0.964, 0.01),
#  'recall_macro': (0.956, 0.013),
#  'recall_weighted': (0.96, 0.013),
#  'score_time': (0.01, 0.0)}
# Total programs: 600
# Dim (opcode count): 89
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
#
# {'C': 30, 'kernel': 'rbf'}
# {'accuracy': (0.963, 0.008),
#  'f1_macro': (0.963, 0.009),
#  'f1_weighted': (0.963, 0.009),
#  'fit_time': (0.009, 0.0),
#  'precision_macro': (0.967, 0.005),
#  'precision_weighted': (0.967, 0.007),
#  'recall_macro': (0.962, 0.01),
#  'recall_weighted': (0.963, 0.008),
#  'score_time': (0.01, 0.001)}
# Total programs: 700
# Dim (opcode count): 89
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
#
# {'C': 30, 'kernel': 'rbf'}
# {'accuracy': (0.966, 0.017),
#  'f1_macro': (0.966, 0.016),
#  'f1_weighted': (0.966, 0.016),
#  'fit_time': (0.011, 0.001),
#  'precision_macro': (0.97, 0.014),
#  'precision_weighted': (0.969, 0.015),
#  'recall_macro': (0.965, 0.016),
#  'recall_weighted': (0.966, 0.017),
#  'score_time': (0.011, 0.0)}
# Total programs: 800
# Dim (opcode count): 89
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
#
# {'C': 30, 'kernel': 'rbf'}
# {'accuracy': (0.965, 0.018),
#  'f1_macro': (0.964, 0.017),
#  'f1_weighted': (0.965, 0.018),
#  'fit_time': (0.012, 0.001),
#  'precision_macro': (0.969, 0.014),
#  'precision_weighted': (0.969, 0.015),
#  'recall_macro': (0.963, 0.018),
#  'recall_weighted': (0.965, 0.018),
#  'score_time': (0.013, 0.001)}
# Total programs: 900
# Dim (opcode count): 91
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
#
# {'C': 30, 'kernel': 'rbf'}
# {'accuracy': (0.973, 0.011),
#  'f1_macro': (0.973, 0.011),
#  'f1_weighted': (0.973, 0.011),
#  'fit_time': (0.018, 0.006),
#  'precision_macro': (0.976, 0.009),
#  'precision_weighted': (0.975, 0.009),
#  'recall_macro': (0.972, 0.012),
#  'recall_weighted': (0.973, 0.011),
#  'score_time': (0.014, 0.001)}
# Total programs: 1000
# Dim (opcode count): 91
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
#
# {'C': 30, 'kernel': 'rbf'}
# {'accuracy': (0.972, 0.012),
#  'f1_macro': (0.972, 0.012),
#  'f1_weighted': (0.972, 0.013),
#  'fit_time': (0.016, 0.001),
#  'precision_macro': (0.974, 0.011),
#  'precision_weighted': (0.974, 0.011),
#  'recall_macro': (0.971, 0.013),
#  'recall_weighted': (0.972, 0.012),
#  'score_time': (0.015, 0.0)}
# [{'accuracy': (0.87, 0.093), 'f1_macro': (0.836, 0.113), 'fit_time': (0.002, 0.0), 'precision_macro': (0.836, 0.116), 'recall_macro': (0.848, 0.103), 'score_time': (0.01, 0.006)},
#  {'accuracy': (0.92, 0.043), 'f1_macro': (0.909, 0.057), 'fit_time': (0.003, 0.0), 'precision_macro': (0.921, 0.061), 'recall_macro': (0.912, 0.051), 'score_time': (0.007, 0.0)},
#  {'accuracy': (0.933, 0.03), 'f1_macro': (0.926, 0.032), 'fit_time': (0.004, 0.0), 'precision_macro': (0.937, 0.03), 'recall_macro': (0.925, 0.034), 'score_time': (0.008, 0.0)},
#  {'accuracy': (0.943, 0.037), 'f1_macro': (0.939, 0.039), 'fit_time': (0.006, 0.0), 'precision_macro': (0.95, 0.037), 'recall_macro': (0.938, 0.036), 'score_time': (0.009, 0.0)},
#  {'accuracy': (0.96, 0.013), 'f1_macro': (0.956, 0.013), 'fit_time': (0.007, 0.001), 'precision_macro': (0.962, 0.011), 'recall_macro': (0.956, 0.013), 'score_time': (0.01, 0.0)},
#  {'accuracy': (0.963, 0.008), 'f1_macro': (0.963, 0.009), 'fit_time': (0.009, 0.0), 'precision_macro': (0.967, 0.005), 'recall_macro': (0.962, 0.01), 'score_time': (0.01, 0.001)},
#  {'accuracy': (0.966, 0.017), 'f1_macro': (0.966, 0.016), 'fit_time': (0.011, 0.001), 'precision_macro': (0.97, 0.014), 'recall_macro': (0.965, 0.016), 'score_time': (0.011, 0.0)},
#  {'accuracy': (0.965, 0.018), 'f1_macro': (0.964, 0.017), 'fit_time': (0.012, 0.001), 'precision_macro': (0.969, 0.014), 'recall_macro': (0.963, 0.018), 'score_time': (0.013, 0.001)},
#  {'accuracy': (0.973, 0.011), 'f1_macro': (0.973, 0.011), 'fit_time': (0.018, 0.006), 'precision_macro': (0.976, 0.009), 'recall_macro': (0.972, 0.012), 'score_time': (0.014, 0.001)},
#  {'accuracy': (0.972, 0.012), 'f1_macro': (0.972, 0.012), 'fit_time': (0.016, 0.001), 'precision_macro': (0.974, 0.011), 'recall_macro': (0.971, 0.013), 'score_time': (0.015, 0.0)}]

# %%
stats = statistics(dataset, RandomForestClassifier, {
    'n_estimators': [300],
    'max_depth': [40],
}, 100, 1000 + 100, 100)
# Out:
# Total programs: 100
# Dim (opcode count): 73
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.4s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.3s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.3s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.3s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.3s
#
# {'max_depth': 40, 'n_estimators': 300}
# {'accuracy': (0.86, 0.073),
#  'f1_macro': (0.806, 0.103),
#  'f1_weighted': (0.841, 0.083),
#  'fit_time': (0.38, 0.027),
#  'precision_macro': (0.816, 0.102),
#  'precision_weighted': (0.855, 0.08),
#  'recall_macro': (0.824, 0.093),
#  'recall_weighted': (0.86, 0.073),
#  'score_time': (0.03, 0.001)}
# Total programs: 200
# Dim (opcode count): 82
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.3s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.3s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.3s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.3s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.4s
#
# {'max_depth': 40, 'n_estimators': 300}
# {'accuracy': (0.94, 0.034),
#  'f1_macro': (0.925, 0.053),
#  'f1_weighted': (0.935, 0.041),
#  'fit_time': (0.413, 0.01),
#  'precision_macro': (0.94, 0.061),
#  'precision_weighted': (0.944, 0.046),
#  'recall_macro': (0.926, 0.045),
#  'recall_weighted': (0.94, 0.034),
#  'score_time': (0.031, 0.001)}
# Total programs: 300
# Dim (opcode count): 84
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.4s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.4s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.4s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.4s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.4s
#
# {'max_depth': 40, 'n_estimators': 300}
# {'accuracy': (0.94, 0.025),
#  'f1_macro': (0.932, 0.031),
#  'f1_weighted': (0.939, 0.025),
#  'fit_time': (0.467, 0.017),
#  'precision_macro': (0.949, 0.022),
#  'precision_weighted': (0.95, 0.019),
#  'recall_macro': (0.93, 0.031),
#  'recall_weighted': (0.94, 0.025),
#  'score_time': (0.034, 0.002)}
# Total programs: 400
# Dim (opcode count): 86
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.4s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.4s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.4s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.4s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.4s
#
# {'max_depth': 40, 'n_estimators': 300}
# {'accuracy': (0.95, 0.035),
#  'f1_macro': (0.945, 0.041),
#  'f1_weighted': (0.95, 0.036),
#  'fit_time': (0.498, 0.007),
#  'precision_macro': (0.954, 0.033),
#  'precision_weighted': (0.957, 0.031),
#  'recall_macro': (0.945, 0.042),
#  'recall_weighted': (0.95, 0.035),
#  'score_time': (0.034, 0.002)}
# Total programs: 500
# Dim (opcode count): 86
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.4s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.5s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.5s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.5s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.5s
#
# {'max_depth': 40, 'n_estimators': 300}
# {'accuracy': (0.97, 0.018),
#  'f1_macro': (0.966, 0.021),
#  'f1_weighted': (0.97, 0.018),
#  'fit_time': (0.525, 0.008),
#  'precision_macro': (0.971, 0.018),
#  'precision_weighted': (0.973, 0.015),
#  'recall_macro': (0.964, 0.022),
#  'recall_weighted': (0.97, 0.018),
#  'score_time': (0.033, 0.001)}
# Total programs: 600
# Dim (opcode count): 89
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.5s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.5s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.5s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.5s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.5s
#
# {'max_depth': 40, 'n_estimators': 300}
# {'accuracy': (0.972, 0.014),
#  'f1_macro': (0.971, 0.013),
#  'f1_weighted': (0.972, 0.013),
#  'fit_time': (0.572, 0.011),
#  'precision_macro': (0.975, 0.011),
#  'precision_weighted': (0.975, 0.011),
#  'recall_macro': (0.971, 0.013),
#  'recall_weighted': (0.972, 0.014),
#  'score_time': (0.035, 0.001)}
# Total programs: 700
# Dim (opcode count): 89
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.6s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.7s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.8s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.6s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.6s
#
# {'max_depth': 40, 'n_estimators': 300}
# {'accuracy': (0.969, 0.01),
#  'f1_macro': (0.968, 0.01),
#  'f1_weighted': (0.968, 0.01),
#  'fit_time': (0.696, 0.079),
#  'precision_macro': (0.971, 0.01),
#  'precision_weighted': (0.971, 0.009),
#  'recall_macro': (0.969, 0.009),
#  'recall_weighted': (0.969, 0.01),
#  'score_time': (0.04, 0.005)}
# Total programs: 800
# Dim (opcode count): 89
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.6s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.6s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.6s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.6s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.6s
#
# {'max_depth': 40, 'n_estimators': 300}
# {'accuracy': (0.974, 0.007),
#  'f1_macro': (0.974, 0.007),
#  'f1_weighted': (0.974, 0.007),
#  'fit_time': (0.668, 0.02),
#  'precision_macro': (0.976, 0.007),
#  'precision_weighted': (0.976, 0.007),
#  'recall_macro': (0.974, 0.007),
#  'recall_weighted': (0.974, 0.007),
#  'score_time': (0.037, 0.001)}
# Total programs: 900
# Dim (opcode count): 91
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.7s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.6s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.6s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.6s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.6s
#
# {'max_depth': 40, 'n_estimators': 300}
# {'accuracy': (0.974, 0.008),
#  'f1_macro': (0.974, 0.009),
#  'f1_weighted': (0.974, 0.008),
#  'fit_time': (0.696, 0.026),
#  'precision_macro': (0.976, 0.007),
#  'precision_weighted': (0.976, 0.007),
#  'recall_macro': (0.974, 0.009),
#  'recall_weighted': (0.974, 0.008),
#  'score_time': (0.038, 0.001)}
# Total programs: 1000
# Dim (opcode count): 91
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.6s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.6s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.7s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.6s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.6s
#
# {'max_depth': 40, 'n_estimators': 300}
# {'accuracy': (0.97, 0.01),
#  'f1_macro': (0.97, 0.01),
#  'f1_weighted': (0.97, 0.01),
#  'fit_time': (0.708, 0.011),
#  'precision_macro': (0.972, 0.008),
#  'precision_weighted': (0.972, 0.009),
#  'recall_macro': (0.97, 0.011),
#  'recall_weighted': (0.97, 0.01),
#  'score_time': (0.039, 0.001)}
# [{'accuracy': (0.86, 0.073), 'f1_macro': (0.806, 0.103), 'fit_time': (0.38, 0.027), 'precision_macro': (0.816, 0.102), 'recall_macro': (0.824, 0.093), 'score_time': (0.03, 0.001)},
#  {'accuracy': (0.94, 0.034), 'f1_macro': (0.925, 0.053), 'fit_time': (0.413, 0.01), 'precision_macro': (0.94, 0.061), 'recall_macro': (0.926, 0.045), 'score_time': (0.031, 0.001)},
#  {'accuracy': (0.94, 0.025), 'f1_macro': (0.932, 0.031), 'fit_time': (0.467, 0.017), 'precision_macro': (0.949, 0.022), 'recall_macro': (0.93, 0.031), 'score_time': (0.034, 0.002)},
#  {'accuracy': (0.95, 0.035), 'f1_macro': (0.945, 0.041), 'fit_time': (0.498, 0.007), 'precision_macro': (0.954, 0.033), 'recall_macro': (0.945, 0.042), 'score_time': (0.034, 0.002)},
#  {'accuracy': (0.97, 0.018), 'f1_macro': (0.966, 0.021), 'fit_time': (0.525, 0.008), 'precision_macro': (0.971, 0.018), 'recall_macro': (0.964, 0.022), 'score_time': (0.033, 0.001)},
#  {'accuracy': (0.972, 0.014), 'f1_macro': (0.971, 0.013), 'fit_time': (0.572, 0.011), 'precision_macro': (0.975, 0.011), 'recall_macro': (0.971, 0.013), 'score_time': (0.035, 0.001)},
#  {'accuracy': (0.969, 0.01), 'f1_macro': (0.968, 0.01), 'fit_time': (0.696, 0.079), 'precision_macro': (0.971, 0.01), 'recall_macro': (0.969, 0.009), 'score_time': (0.04, 0.005)},
#  {'accuracy': (0.974, 0.007), 'f1_macro': (0.974, 0.007), 'fit_time': (0.668, 0.02), 'precision_macro': (0.976, 0.007), 'recall_macro': (0.974, 0.007), 'score_time': (0.037, 0.001)},
#  {'accuracy': (0.974, 0.008), 'f1_macro': (0.974, 0.009), 'fit_time': (0.696, 0.026), 'precision_macro': (0.976, 0.007), 'recall_macro': (0.974, 0.009), 'score_time': (0.038, 0.001)},
#  {'accuracy': (0.97, 0.01), 'f1_macro': (0.97, 0.01), 'fit_time': (0.708, 0.011), 'precision_macro': (0.972, 0.008), 'recall_macro': (0.97, 0.011), 'score_time': (0.039, 0.001)}]

# %%
stats = statistics(dataset, MLPClassifier, {
    'activation': ['relu'],
    'learning_rate_init': [0.001],
}, 100, 1000 + 100, 100)
# Out:
# Total programs: 100
# Dim (opcode count): 73
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   0.1s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   0.1s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   0.1s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   0.1s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   0.1s
#
# {'activation': 'relu', 'learning_rate_init': 0.001}
# {'accuracy': (0.59, 0.097),
#  'f1_macro': (0.456, 0.114),
#  'f1_weighted': (0.495, 0.127),
#  'fit_time': (0.181, 0.016),
#  'precision_macro': (0.433, 0.13),
#  'precision_weighted': (0.465, 0.146),
#  'recall_macro': (0.535, 0.081),
#  'recall_weighted': (0.59, 0.097),
#  'score_time': (0.007, 0.0)}
# Total programs: 200
# Dim (opcode count): 82
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   0.1s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   0.1s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   0.1s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   0.1s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   0.1s
#
# {'activation': 'relu', 'learning_rate_init': 0.001}
# {'accuracy': (0.67, 0.051),
#  'f1_macro': (0.564, 0.084),
#  'f1_weighted': (0.601, 0.067),
#  'fit_time': (0.197, 0.004),
#  'precision_macro': (0.602, 0.114),
#  'precision_weighted': (0.629, 0.102),
#  'recall_macro': (0.615, 0.07),
#  'recall_weighted': (0.67, 0.051),
#  'score_time': (0.007, 0.001)}
# Total programs: 300
# Dim (opcode count): 84
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   0.3s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   0.3s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   0.3s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   0.3s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   0.3s
#
# {'activation': 'relu', 'learning_rate_init': 0.001}
# {'accuracy': (0.79, 0.047),
#  'f1_macro': (0.725, 0.065),
#  'f1_weighted': (0.755, 0.054),
#  'fit_time': (0.368, 0.016),
#  'precision_macro': (0.77, 0.094),
#  'precision_weighted': (0.784, 0.075),
#  'recall_macro': (0.748, 0.055),
#  'recall_weighted': (0.79, 0.047),
#  'score_time': (0.007, 0.001)}
# Total programs: 400
# Dim (opcode count): 86
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   0.3s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   0.3s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   0.3s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   0.3s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   0.3s
#
# {'activation': 'relu', 'learning_rate_init': 0.001}
# {'accuracy': (0.828, 0.044),
#  'f1_macro': (0.765, 0.041),
#  'f1_weighted': (0.799, 0.04),
#  'fit_time': (0.375, 0.011),
#  'precision_macro': (0.801, 0.052),
#  'precision_weighted': (0.815, 0.04),
#  'recall_macro': (0.785, 0.044),
#  'recall_weighted': (0.828, 0.044),
#  'score_time': (0.006, 0.003)}
# Total programs: 500
# Dim (opcode count): 86
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   0.3s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   0.3s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   0.3s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   0.3s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   0.3s
#
# {'activation': 'relu', 'learning_rate_init': 0.001}
# {'accuracy': (0.834, 0.03),
#  'f1_macro': (0.778, 0.031),
#  'f1_weighted': (0.811, 0.029),
#  'fit_time': (0.394, 0.007),
#  'precision_macro': (0.836, 0.038),
#  'precision_weighted': (0.843, 0.03),
#  'recall_macro': (0.794, 0.032),
#  'recall_weighted': (0.834, 0.03),
#  'score_time': (0.008, 0.004)}
# Total programs: 600
# Dim (opcode count): 89
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   0.5s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   0.5s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   0.5s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   0.5s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   0.5s
#
# {'activation': 'relu', 'learning_rate_init': 0.001}
# {'accuracy': (0.875, 0.027),
#  'f1_macro': (0.86, 0.03),
#  'f1_weighted': (0.87, 0.027),
#  'fit_time': (0.604, 0.024),
#  'precision_macro': (0.893, 0.033),
#  'precision_weighted': (0.894, 0.03),
#  'recall_macro': (0.859, 0.031),
#  'recall_weighted': (0.875, 0.027),
#  'score_time': (0.006, 0.003)}
# Total programs: 700
# Dim (opcode count): 89
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   0.5s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   0.5s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   0.5s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   0.5s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   0.5s
#
# {'activation': 'relu', 'learning_rate_init': 0.001}
# {'accuracy': (0.884, 0.018),
#  'f1_macro': (0.876, 0.018),
#  'f1_weighted': (0.884, 0.016),
#  'fit_time': (0.558, 0.004),
#  'precision_macro': (0.895, 0.019),
#  'precision_weighted': (0.899, 0.015),
#  'recall_macro': (0.873, 0.018),
#  'recall_weighted': (0.884, 0.018),
#  'score_time': (0.012, 0.004)}
# Total programs: 800
# Dim (opcode count): 89
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   0.6s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   0.7s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   0.7s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   0.7s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   0.7s
#
# {'activation': 'relu', 'learning_rate_init': 0.001}
# {'accuracy': (0.906, 0.038),
#  'f1_macro': (0.901, 0.039),
#  'f1_weighted': (0.906, 0.037),
#  'fit_time': (0.757, 0.016),
#  'precision_macro': (0.913, 0.037),
#  'precision_weighted': (0.916, 0.034),
#  'recall_macro': (0.899, 0.039),
#  'recall_weighted': (0.906, 0.038),
#  'score_time': (0.007, 0.005)}
# Total programs: 900
# Dim (opcode count): 91
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   0.7s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   0.7s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   0.7s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   0.7s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   0.7s
#
# {'activation': 'relu', 'learning_rate_init': 0.001}
# {'accuracy': (0.926, 0.017),
#  'f1_macro': (0.923, 0.018),
#  'f1_weighted': (0.926, 0.017),
#  'fit_time': (0.781, 0.011),
#  'precision_macro': (0.93, 0.017),
#  'precision_weighted': (0.932, 0.016),
#  'recall_macro': (0.922, 0.019),
#  'recall_weighted': (0.926, 0.017),
#  'score_time': (0.01, 0.005)}
# Total programs: 1000
# Dim (opcode count): 91
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   0.7s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   0.7s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   0.8s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   0.7s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   0.7s
#
# {'activation': 'relu', 'learning_rate_init': 0.001}
# {'accuracy': (0.913, 0.019),
#  'f1_macro': (0.911, 0.019),
#  'f1_weighted': (0.914, 0.02),
#  'fit_time': (0.831, 0.056),
#  'precision_macro': (0.919, 0.017),
#  'precision_weighted': (0.921, 0.018),
#  'recall_macro': (0.91, 0.02),
#  'recall_weighted': (0.913, 0.019),
#  'score_time': (0.002, 0.003)}
# [{'accuracy': (0.59, 0.097), 'f1_macro': (0.456, 0.114), 'fit_time': (0.181, 0.016), 'precision_macro': (0.433, 0.13), 'recall_macro': (0.535, 0.081), 'score_time': (0.007, 0.0)},
#  {'accuracy': (0.67, 0.051), 'f1_macro': (0.564, 0.084), 'fit_time': (0.197, 0.004), 'precision_macro': (0.602, 0.114), 'recall_macro': (0.615, 0.07), 'score_time': (0.007, 0.001)},
#  {'accuracy': (0.79, 0.047), 'f1_macro': (0.725, 0.065), 'fit_time': (0.368, 0.016), 'precision_macro': (0.77, 0.094), 'recall_macro': (0.748, 0.055), 'score_time': (0.007, 0.001)},
#  {'accuracy': (0.828, 0.044), 'f1_macro': (0.765, 0.041), 'fit_time': (0.375, 0.011), 'precision_macro': (0.801, 0.052), 'recall_macro': (0.785, 0.044), 'score_time': (0.006, 0.003)},
#  {'accuracy': (0.834, 0.03), 'f1_macro': (0.778, 0.031), 'fit_time': (0.394, 0.007), 'precision_macro': (0.836, 0.038), 'recall_macro': (0.794, 0.032), 'score_time': (0.008, 0.004)},
#  {'accuracy': (0.875, 0.027), 'f1_macro': (0.86, 0.03), 'fit_time': (0.604, 0.024), 'precision_macro': (0.893, 0.033), 'recall_macro': (0.859, 0.031), 'score_time': (0.006, 0.003)},
#  {'accuracy': (0.884, 0.018), 'f1_macro': (0.876, 0.018), 'fit_time': (0.558, 0.004), 'precision_macro': (0.895, 0.019), 'recall_macro': (0.873, 0.018), 'score_time': (0.012, 0.004)},
#  {'accuracy': (0.906, 0.038), 'f1_macro': (0.901, 0.039), 'fit_time': (0.757, 0.016), 'precision_macro': (0.913, 0.037), 'recall_macro': (0.899, 0.039), 'score_time': (0.007, 0.005)},
#  {'accuracy': (0.926, 0.017), 'f1_macro': (0.923, 0.018), 'fit_time': (0.781, 0.011), 'precision_macro': (0.93, 0.017), 'recall_macro': (0.922, 0.019), 'score_time': (0.01, 0.005)},
#  {'accuracy': (0.913, 0.019), 'f1_macro': (0.911, 0.019), 'fit_time': (0.831, 0.056), 'precision_macro': (0.919, 0.017), 'recall_macro': (0.91, 0.02), 'score_time': (0.002, 0.003)}]
