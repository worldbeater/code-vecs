# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import RandomForestClassifier
from utilities import read_dataset_folder, describe, statistics

import random
import markov
import numpy as np

MM = {
    "Module": None,
    "keyword": None,
    "Return": "Assign",
    "Attribute": "Name",
}

def rename(names):
    new = ()
    for name in names:
        value = MM.get(name, name)
        if value is None:
            return None
        new += (value,)
    return new

def markov_n2(vertices, edges):
    vertices, edges = markov.lift(vertices, edges, vertices.get)
    return markov.markov(vertices, edges, lambda n: rename(vertices[n]))

def dataset(folder='data', count=2000):
    random.seed(42)
    programs, labels = zip(*random.sample(read_dataset_folder(folder), count))
    print(f'Total programs: {len(programs)}')
    vectors = markov.vectorize(programs, markov.graph, markov_n2)
    h = next(vectors)
    x = np.array(list(vectors), dtype=np.float32)
    y = np.array(labels, dtype=int).reshape((len(labels), 1))
    return h, x, y

describe(dataset)
# Out:
# Total programs: 100
# Vectorized 100 chains...
# Components: 36864.
# Non-zero components: 25.
# Zero components: 36839.

# %% [markdown]
# **Plots 100-1000**

# %%
stats = statistics(dataset, KNeighborsClassifier, {
    'n_neighbors': [4],
    'weights': ('distance',),
    'metric': ('manhattan',)
}, 100, 1000 + 100, 100)
# Out:
# Total programs: 100
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.1s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
#
# {'metric': 'manhattan', 'n_neighbors': 4, 'weights': 'distance'}
# {'accuracy': (0.7, 0.105),
#  'f1_macro': (0.621, 0.113),
#  'f1_weighted': (0.667, 0.128),
#  'fit_time': (0.008, 0.001),
#  'precision_macro': (0.633, 0.127),
#  'precision_weighted': (0.685, 0.151),
#  'recall_macro': (0.661, 0.091),
#  'recall_weighted': (0.7, 0.105),
#  'score_time': (0.094, 0.047)}
# Total programs: 200
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.2s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.3s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.2s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.2s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.3s
#
# {'metric': 'manhattan', 'n_neighbors': 4, 'weights': 'distance'}
# {'accuracy': (0.84, 0.054),
#  'f1_macro': (0.832, 0.048),
#  'f1_weighted': (0.84, 0.047),
#  'fit_time': (0.021, 0.002),
#  'precision_macro': (0.873, 0.045),
#  'precision_weighted': (0.897, 0.031),
#  'recall_macro': (0.846, 0.047),
#  'recall_weighted': (0.84, 0.054),
#  'score_time': (0.327, 0.008)}
# Total programs: 300
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.7s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.7s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.7s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.7s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.7s
#
# {'metric': 'manhattan', 'n_neighbors': 4, 'weights': 'distance'}
# {'accuracy': (0.87, 0.041),
#  'f1_macro': (0.863, 0.044),
#  'f1_weighted': (0.87, 0.04),
#  'fit_time': (0.033, 0.003),
#  'precision_macro': (0.912, 0.021),
#  'precision_weighted': (0.911, 0.023),
#  'recall_macro': (0.859, 0.048),
#  'recall_weighted': (0.87, 0.041),
#  'score_time': (0.763, 0.005)}
# Total programs: 400
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   1.1s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   1.2s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   1.1s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   1.1s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   1.1s
#
# {'metric': 'manhattan', 'n_neighbors': 4, 'weights': 'distance'}
# {'accuracy': (0.898, 0.035),
#  'f1_macro': (0.894, 0.041),
#  'f1_weighted': (0.896, 0.037),
#  'fit_time': (0.05, 0.011),
#  'precision_macro': (0.93, 0.019),
#  'precision_weighted': (0.926, 0.021),
#  'recall_macro': (0.891, 0.044),
#  'recall_weighted': (0.898, 0.035),
#  'score_time': (1.174, 0.023)}
# Total programs: 500
# Processed 500 snippets...
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   1.6s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   1.6s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   1.6s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   1.6s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   1.6s
#
# {'metric': 'manhattan', 'n_neighbors': 4, 'weights': 'distance'}
# {'accuracy': (0.902, 0.041),
#  'f1_macro': (0.897, 0.043),
#  'f1_weighted': (0.9, 0.042),
#  'fit_time': (0.058, 0.005),
#  'precision_macro': (0.934, 0.024),
#  'precision_weighted': (0.929, 0.026),
#  'recall_macro': (0.893, 0.043),
#  'recall_weighted': (0.902, 0.041),
#  'score_time': (1.624, 0.02)}
# Total programs: 600
# Processed 500 snippets...
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   2.1s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   2.1s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   2.1s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   2.1s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   2.1s
#
# {'metric': 'manhattan', 'n_neighbors': 4, 'weights': 'distance'}
# {'accuracy': (0.908, 0.028),
#  'f1_macro': (0.905, 0.028),
#  'f1_weighted': (0.907, 0.028),
#  'fit_time': (0.078, 0.002),
#  'precision_macro': (0.933, 0.015),
#  'precision_weighted': (0.931, 0.015),
#  'recall_macro': (0.904, 0.028),
#  'recall_weighted': (0.908, 0.028),
#  'score_time': (2.146, 0.016)}
# Total programs: 700
# Processed 500 snippets...
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   2.6s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   2.6s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   2.8s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   2.6s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   2.6s
#
# {'metric': 'manhattan', 'n_neighbors': 4, 'weights': 'distance'}
# {'accuracy': (0.914, 0.022),
#  'f1_macro': (0.912, 0.023),
#  'f1_weighted': (0.913, 0.022),
#  'fit_time': (0.085, 0.005),
#  'precision_macro': (0.934, 0.015),
#  'precision_weighted': (0.933, 0.015),
#  'recall_macro': (0.912, 0.023),
#  'recall_weighted': (0.914, 0.022),
#  'score_time': (2.658, 0.075)}
# Total programs: 800
# Processed 500 snippets...
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   3.3s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   3.4s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   3.3s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   3.2s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   3.2s
#
# {'metric': 'manhattan', 'n_neighbors': 4, 'weights': 'distance'}
# {'accuracy': (0.925, 0.019),
#  'f1_macro': (0.923, 0.02),
#  'f1_weighted': (0.924, 0.02),
#  'fit_time': (0.11, 0.006),
#  'precision_macro': (0.942, 0.011),
#  'precision_weighted': (0.942, 0.011),
#  'recall_macro': (0.924, 0.019),
#  'recall_weighted': (0.925, 0.019),
#  'score_time': (3.273, 0.057)}
# Total programs: 900
# Processed 500 snippets...
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   3.8s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   3.8s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   3.8s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   4.0s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   3.8s
#
# {'metric': 'manhattan', 'n_neighbors': 4, 'weights': 'distance'}
# {'accuracy': (0.926, 0.011),
#  'f1_macro': (0.924, 0.012),
#  'f1_weighted': (0.924, 0.011),
#  'fit_time': (0.118, 0.007),
#  'precision_macro': (0.941, 0.008),
#  'precision_weighted': (0.941, 0.008),
#  'recall_macro': (0.925, 0.013),
#  'recall_weighted': (0.926, 0.011),
#  'score_time': (3.816, 0.064)}
# Total programs: 1000
# Processed 500 snippets...
# Processed 1000 snippets...
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   4.4s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   4.4s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   4.4s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   4.5s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   4.6s
#
# {'metric': 'manhattan', 'n_neighbors': 4, 'weights': 'distance'}
# {'accuracy': (0.925, 0.023),
#  'f1_macro': (0.923, 0.024),
#  'f1_weighted': (0.923, 0.024),
#  'fit_time': (0.136, 0.009),
#  'precision_macro': (0.94, 0.014),
#  'precision_weighted': (0.939, 0.015),
#  'recall_macro': (0.924, 0.024),
#  'recall_weighted': (0.925, 0.023),
#  'score_time': (4.428, 0.041)}
# [{'accuracy': (0.7, 0.105),
#   'f1_macro': (0.621, 0.113),
#   'fit_time': (0.008, 0.001),
#   'precision_macro': (0.633, 0.127),
#   'recall_macro': (0.661, 0.091),
#   'score_time': (0.094, 0.047)},
#  {'accuracy': (0.84, 0.054),
#   'f1_macro': (0.832, 0.048),
#   'fit_time': (0.021, 0.002),
#   'precision_macro': (0.873, 0.045),
#   'recall_macro': (0.846, 0.047),
#   'score_time': (0.327, 0.008)},
#  {'accuracy': (0.87, 0.041),
#   'f1_macro': (0.863, 0.044),
#   'fit_time': (0.033, 0.003),
#   'precision_macro': (0.912, 0.021),
#   'recall_macro': (0.859, 0.048),
#   'score_time': (0.763, 0.005)},
#  {'accuracy': (0.898, 0.035),
#   'f1_macro': (0.894, 0.041),
#   'fit_time': (0.05, 0.011),
#   'precision_macro': (0.93, 0.019),
#   'recall_macro': (0.891, 0.044),
#   'score_time': (1.174, 0.023)},
#  {'accuracy': (0.902, 0.041),
#   'f1_macro': (0.897, 0.043),
#   'fit_time': (0.058, 0.005),
#   'precision_macro': (0.934, 0.024),
#   'recall_macro': (0.893, 0.043),
#   'score_time': (1.624, 0.02)},
#  {'accuracy': (0.908, 0.028),
#   'f1_macro': (0.905, 0.028),
#   'fit_time': (0.078, 0.002),
#   'precision_macro': (0.933, 0.015),
#   'recall_macro': (0.904, 0.028),
#   'score_time': (2.146, 0.016)},
#  {'accuracy': (0.914, 0.022),
#   'f1_macro': (0.912, 0.023),
#   'fit_time': (0.085, 0.005),
#   'precision_macro': (0.934, 0.015),
#   'recall_macro': (0.912, 0.023),
#   'score_time': (2.658, 0.075)},
#  {'accuracy': (0.925, 0.019),
#   'f1_macro': (0.923, 0.02),
#   'fit_time': (0.11, 0.006),
#   'precision_macro': (0.942, 0.011),
#   'recall_macro': (0.924, 0.019),
#   'score_time': (3.273, 0.057)},
#  {'accuracy': (0.926, 0.011),
#   'f1_macro': (0.924, 0.012),
#   'fit_time': (0.118, 0.007),
#   'precision_macro': (0.941, 0.008),
#   'recall_macro': (0.925, 0.013),
#   'score_time': (3.816, 0.064)},
#  {'accuracy': (0.925, 0.023),
#   'f1_macro': (0.923, 0.024),
#   'fit_time': (0.136, 0.009),
#   'precision_macro': (0.94, 0.014),
#   'recall_macro': (0.924, 0.024),
#   'score_time': (4.428, 0.041)}]

# %%
stats = statistics(dataset, SVC, {
    'C': [30],
    'kernel': ('rbf',),
}, 100, 1000 + 100, 100)
# Out:
# Total programs: 100
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ...................................C=30, kernel=rbf; total time=   1.2s
# [CV] END ...................................C=30, kernel=rbf; total time=   1.1s
# [CV] END ...................................C=30, kernel=rbf; total time=   1.1s
# [CV] END ...................................C=30, kernel=rbf; total time=   1.1s
# [CV] END ...................................C=30, kernel=rbf; total time=   1.1s
#
# {'C': 30, 'kernel': 'rbf'}
# {'accuracy': (0.83, 0.068),
#  'f1_macro': (0.75, 0.077),
#  'f1_weighted': (0.808, 0.086),
#  'fit_time': (1.049, 0.015),
#  'precision_macro': (0.754, 0.082),
#  'precision_weighted': (0.819, 0.095),
#  'recall_macro': (0.776, 0.065),
#  'recall_weighted': (0.83, 0.068),
#  'score_time': (0.189, 0.005)}
# Total programs: 200
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ...................................C=30, kernel=rbf; total time=   4.6s
# [CV] END ...................................C=30, kernel=rbf; total time=   4.6s
# [CV] END ...................................C=30, kernel=rbf; total time=   4.7s
# [CV] END ...................................C=30, kernel=rbf; total time=   4.7s
# [CV] END ...................................C=30, kernel=rbf; total time=   4.7s
#
# {'C': 30, 'kernel': 'rbf'}
# {'accuracy': (0.91, 0.044),
#  'f1_macro': (0.906, 0.04),
#  'f1_weighted': (0.911, 0.042),
#  'fit_time': (3.983, 0.053),
#  'precision_macro': (0.931, 0.037),
#  'precision_weighted': (0.929, 0.036),
#  'recall_macro': (0.902, 0.04),
#  'recall_weighted': (0.91, 0.044),
#  'score_time': (0.789, 0.015)}
# Total programs: 300
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ...................................C=30, kernel=rbf; total time=   8.9s
# [CV] END ...................................C=30, kernel=rbf; total time=   8.7s
# [CV] END ...................................C=30, kernel=rbf; total time=   9.0s
# [CV] END ...................................C=30, kernel=rbf; total time=   9.2s
# [CV] END ...................................C=30, kernel=rbf; total time=   9.0s
#
# {'C': 30, 'kernel': 'rbf'}
# {'accuracy': (0.923, 0.039),
#  'f1_macro': (0.918, 0.043),
#  'f1_weighted': (0.923, 0.04),
#  'fit_time': (7.453, 0.169),
#  'precision_macro': (0.943, 0.032),
#  'precision_weighted': (0.94, 0.032),
#  'recall_macro': (0.911, 0.045),
#  'recall_weighted': (0.923, 0.039),
#  'score_time': (1.61, 0.022)}
# Total programs: 400
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ...................................C=30, kernel=rbf; total time=  14.0s
# [CV] END ...................................C=30, kernel=rbf; total time=  14.2s
# [CV] END ...................................C=30, kernel=rbf; total time=  14.2s
# [CV] END ...................................C=30, kernel=rbf; total time=  14.0s
# [CV] END ...................................C=30, kernel=rbf; total time=  13.8s
#
# {'C': 30, 'kernel': 'rbf'}
# {'accuracy': (0.945, 0.031),
#  'f1_macro': (0.942, 0.032),
#  'f1_weighted': (0.946, 0.03),
#  'fit_time': (11.34, 0.191),
#  'precision_macro': (0.957, 0.023),
#  'precision_weighted': (0.955, 0.023),
#  'recall_macro': (0.939, 0.034),
#  'recall_weighted': (0.945, 0.031),
#  'score_time': (2.807, 0.056)}
# Total programs: 500
# Processed 500 snippets...
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ...................................C=30, kernel=rbf; total time=  19.9s
# [CV] END ...................................C=30, kernel=rbf; total time=  19.8s
# [CV] END ...................................C=30, kernel=rbf; total time=  19.6s
# [CV] END ...................................C=30, kernel=rbf; total time=  20.1s
# [CV] END ...................................C=30, kernel=rbf; total time=  20.0s
#
# {'C': 30, 'kernel': 'rbf'}
# {'accuracy': (0.954, 0.023),
#  'f1_macro': (0.951, 0.022),
#  'f1_weighted': (0.955, 0.022),
#  'fit_time': (15.732, 0.215),
#  'precision_macro': (0.964, 0.017),
#  'precision_weighted': (0.963, 0.018),
#  'recall_macro': (0.948, 0.024),
#  'recall_weighted': (0.954, 0.023),
#  'score_time': (4.256, 0.074)}
# Total programs: 600
# Processed 500 snippets...
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ...................................C=30, kernel=rbf; total time=  26.9s
# [CV] END ...................................C=30, kernel=rbf; total time=  27.8s
# [CV] END ...................................C=30, kernel=rbf; total time=  27.7s
# [CV] END ...................................C=30, kernel=rbf; total time=  27.3s
# [CV] END ...................................C=30, kernel=rbf; total time=  27.3s
#
# {'C': 30, 'kernel': 'rbf'}
# {'accuracy': (0.958, 0.017),
#  'f1_macro': (0.958, 0.017),
#  'f1_weighted': (0.959, 0.017),
#  'fit_time': (20.99, 0.21),
#  'precision_macro': (0.967, 0.014),
#  'precision_weighted': (0.965, 0.015),
#  'recall_macro': (0.955, 0.019),
#  'recall_weighted': (0.958, 0.017),
#  'score_time': (6.515, 0.111)}
# Total programs: 700
# Processed 500 snippets...
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ...................................C=30, kernel=rbf; total time=  34.6s
# [CV] END ...................................C=30, kernel=rbf; total time=  36.3s
# [CV] END ...................................C=30, kernel=rbf; total time=  34.1s
# [CV] END ...................................C=30, kernel=rbf; total time=  34.1s
# [CV] END ...................................C=30, kernel=rbf; total time=  34.7s
#
# {'C': 30, 'kernel': 'rbf'}
# {'accuracy': (0.97, 0.01),
#  'f1_macro': (0.97, 0.009),
#  'f1_weighted': (0.97, 0.01),
#  'fit_time': (26.167, 0.589),
#  'precision_macro': (0.975, 0.008),
#  'precision_weighted': (0.974, 0.009),
#  'recall_macro': (0.969, 0.01),
#  'recall_weighted': (0.97, 0.01),
#  'score_time': (8.697, 0.217)}
# Total programs: 800
# Processed 500 snippets...
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ...................................C=30, kernel=rbf; total time=  41.3s
# [CV] END ...................................C=30, kernel=rbf; total time=  43.2s
# [CV] END ...................................C=30, kernel=rbf; total time=  41.7s
# [CV] END ...................................C=30, kernel=rbf; total time=  41.2s
# [CV] END ...................................C=30, kernel=rbf; total time=  43.2s
#
# {'C': 30, 'kernel': 'rbf'}
# {'accuracy': (0.97, 0.016),
#  'f1_macro': (0.97, 0.015),
#  'f1_weighted': (0.97, 0.015),
#  'fit_time': (31.14, 0.582),
#  'precision_macro': (0.974, 0.014),
#  'precision_weighted': (0.973, 0.014),
#  'recall_macro': (0.969, 0.016),
#  'recall_weighted': (0.97, 0.016),
#  'score_time': (11.09, 0.366)}
# Total programs: 900
# Processed 500 snippets...
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ...................................C=30, kernel=rbf; total time=  49.8s
# [CV] END ...................................C=30, kernel=rbf; total time=  50.0s
# [CV] END ...................................C=30, kernel=rbf; total time=  49.2s
# [CV] END ...................................C=30, kernel=rbf; total time=  50.1s
# [CV] END ...................................C=30, kernel=rbf; total time=  51.5s
#
# {'C': 30, 'kernel': 'rbf'}
# {'accuracy': (0.97, 0.011),
#  'f1_macro': (0.97, 0.011),
#  'f1_weighted': (0.97, 0.011),
#  'fit_time': (36.65, 0.65),
#  'precision_macro': (0.974, 0.01),
#  'precision_weighted': (0.973, 0.01),
#  'recall_macro': (0.969, 0.011),
#  'recall_weighted': (0.97, 0.011),
#  'score_time': (13.559, 0.273)}
# Total programs: 1000
# Processed 500 snippets...
# Processed 1000 snippets...
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ...................................C=30, kernel=rbf; total time=  59.1s
# [CV] END ...................................C=30, kernel=rbf; total time= 1.0min
# [CV] END ...................................C=30, kernel=rbf; total time=  58.2s
# [CV] END ...................................C=30, kernel=rbf; total time= 1.0min
# [CV] END ...................................C=30, kernel=rbf; total time=  59.2s
#
# {'C': 30, 'kernel': 'rbf'}
# {'accuracy': (0.97, 0.017),
#  'f1_macro': (0.97, 0.017),
#  'f1_weighted': (0.97, 0.017),
#  'fit_time': (43.142, 0.861),
#  'precision_macro': (0.973, 0.015),
#  'precision_weighted': (0.973, 0.015),
#  'recall_macro': (0.969, 0.018),
#  'recall_weighted': (0.97, 0.017),
#  'score_time': (16.515, 0.271)}
# [{'accuracy': (0.83, 0.068),
#   'f1_macro': (0.75, 0.077),
#   'fit_time': (1.049, 0.015),
#   'precision_macro': (0.754, 0.082),
#   'recall_macro': (0.776, 0.065),
#   'score_time': (0.189, 0.005)},
#  {'accuracy': (0.91, 0.044),
#   'f1_macro': (0.906, 0.04),
#   'fit_time': (3.983, 0.053),
#   'precision_macro': (0.931, 0.037),
#   'recall_macro': (0.902, 0.04),
#   'score_time': (0.789, 0.015)},
#  {'accuracy': (0.923, 0.039),
#   'f1_macro': (0.918, 0.043),
#   'fit_time': (7.453, 0.169),
#   'precision_macro': (0.943, 0.032),
#   'recall_macro': (0.911, 0.045),
#   'score_time': (1.61, 0.022)},
#  {'accuracy': (0.945, 0.031),
#   'f1_macro': (0.942, 0.032),
#   'fit_time': (11.34, 0.191),
#   'precision_macro': (0.957, 0.023),
#   'recall_macro': (0.939, 0.034),
#   'score_time': (2.807, 0.056)},
#  {'accuracy': (0.954, 0.023),
#   'f1_macro': (0.951, 0.022),
#   'fit_time': (15.732, 0.215),
#   'precision_macro': (0.964, 0.017),
#   'recall_macro': (0.948, 0.024),
#   'score_time': (4.256, 0.074)},
#  {'accuracy': (0.958, 0.017),
#   'f1_macro': (0.958, 0.017),
#   'fit_time': (20.99, 0.21),
#   'precision_macro': (0.967, 0.014),
#   'recall_macro': (0.955, 0.019),
#   'score_time': (6.515, 0.111)},
#  {'accuracy': (0.97, 0.01),
#   'f1_macro': (0.97, 0.009),
#   'fit_time': (26.167, 0.589),
#   'precision_macro': (0.975, 0.008),
#   'recall_macro': (0.969, 0.01),
#   'score_time': (8.697, 0.217)},
#  {'accuracy': (0.97, 0.016),
#   'f1_macro': (0.97, 0.015),
#   'fit_time': (31.14, 0.582),
#   'precision_macro': (0.974, 0.014),
#   'recall_macro': (0.969, 0.016),
#   'score_time': (11.09, 0.366)},
#  {'accuracy': (0.97, 0.011),
#   'f1_macro': (0.97, 0.011),
#   'fit_time': (36.65, 0.65),
#   'precision_macro': (0.974, 0.01),
#   'recall_macro': (0.969, 0.011),
#   'score_time': (13.559, 0.273)},
#  {'accuracy': (0.97, 0.017),
#   'f1_macro': (0.97, 0.017),
#   'fit_time': (43.142, 0.861),
#   'precision_macro': (0.973, 0.015),
#   'recall_macro': (0.969, 0.018),
#   'score_time': (16.515, 0.271)}]

# %%
stats = statistics(dataset, RandomForestClassifier, {
    'n_estimators': [300],
    'max_depth': [40],
}, 100, 1000 + 100, 100)
# Out:
# Total programs: 100
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END .....................max_depth=40, n_estimators=300; total time=   1.1s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   1.3s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   1.1s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   1.1s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   1.1s
#
# {'max_depth': 40, 'n_estimators': 300}
# {'accuracy': (0.91, 0.058),
#  'f1_macro': (0.871, 0.094),
#  'f1_weighted': (0.893, 0.072),
#  'fit_time': (1.22, 0.089),
#  'precision_macro': (0.882, 0.094),
#  'precision_weighted': (0.91, 0.066),
#  'recall_macro': (0.888, 0.081),
#  'recall_weighted': (0.91, 0.058),
#  'score_time': (0.037, 0.005)}
# Total programs: 200
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END .....................max_depth=40, n_estimators=300; total time=   3.0s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   3.0s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   3.3s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   3.0s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   2.9s
#
# {'max_depth': 40, 'n_estimators': 300}
# {'accuracy': (0.935, 0.041),
#  'f1_macro': (0.92, 0.055),
#  'f1_weighted': (0.93, 0.045),
#  'fit_time': (3.07, 0.125),
#  'precision_macro': (0.935, 0.059),
#  'precision_weighted': (0.941, 0.044),
#  'recall_macro': (0.922, 0.047),
#  'recall_weighted': (0.935, 0.041),
#  'score_time': (0.038, 0.001)}
# Total programs: 300
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END .....................max_depth=40, n_estimators=300; total time=   5.1s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   4.9s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   5.0s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   4.9s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   5.1s
#
# {'max_depth': 40, 'n_estimators': 300}
# {'accuracy': (0.953, 0.029),
#  'f1_macro': (0.946, 0.032),
#  'f1_weighted': (0.953, 0.029),
#  'fit_time': (5.063, 0.079),
#  'precision_macro': (0.962, 0.024),
#  'precision_weighted': (0.963, 0.024),
#  'recall_macro': (0.942, 0.034),
#  'recall_weighted': (0.953, 0.029),
#  'score_time': (0.042, 0.001)}
# Total programs: 400
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END .....................max_depth=40, n_estimators=300; total time=   7.2s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   7.6s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   7.3s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   7.3s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   7.6s
#
# {'max_depth': 40, 'n_estimators': 300}
# {'accuracy': (0.957, 0.044),
#  'f1_macro': (0.955, 0.046),
#  'f1_weighted': (0.957, 0.044),
#  'fit_time': (7.464, 0.156),
#  'precision_macro': (0.965, 0.036),
#  'precision_weighted': (0.964, 0.036),
#  'recall_macro': (0.953, 0.048),
#  'recall_weighted': (0.957, 0.044),
#  'score_time': (0.046, 0.001)}
# Total programs: 500
# Processed 500 snippets...
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END .....................max_depth=40, n_estimators=300; total time=  10.2s
# [CV] END .....................max_depth=40, n_estimators=300; total time=  10.0s
# [CV] END .....................max_depth=40, n_estimators=300; total time=  10.0s
# [CV] END .....................max_depth=40, n_estimators=300; total time=  10.3s
# [CV] END .....................max_depth=40, n_estimators=300; total time=  10.3s
#
# {'max_depth': 40, 'n_estimators': 300}
# {'accuracy': (0.978, 0.021),
#  'f1_macro': (0.977, 0.024),
#  'f1_weighted': (0.978, 0.021),
#  'fit_time': (10.223, 0.118),
#  'precision_macro': (0.981, 0.019),
#  'precision_weighted': (0.981, 0.018),
#  'recall_macro': (0.976, 0.024),
#  'recall_weighted': (0.978, 0.021),
#  'score_time': (0.049, 0.001)}
# Total programs: 600
# Processed 500 snippets...
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END .....................max_depth=40, n_estimators=300; total time=  14.7s
# [CV] END .....................max_depth=40, n_estimators=300; total time=  14.3s
# [CV] END .....................max_depth=40, n_estimators=300; total time=  14.5s
# [CV] END .....................max_depth=40, n_estimators=300; total time=  14.6s
# [CV] END .....................max_depth=40, n_estimators=300; total time=  14.6s
#
# {'max_depth': 40, 'n_estimators': 300}
# {'accuracy': (0.977, 0.016),
#  'f1_macro': (0.975, 0.017),
#  'f1_weighted': (0.977, 0.016),
#  'fit_time': (14.574, 0.133),
#  'precision_macro': (0.979, 0.015),
#  'precision_weighted': (0.979, 0.014),
#  'recall_macro': (0.975, 0.017),
#  'recall_weighted': (0.977, 0.016),
#  'score_time': (0.054, 0.001)}
# Total programs: 700
# Processed 500 snippets...
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END .....................max_depth=40, n_estimators=300; total time=  17.7s
# [CV] END .....................max_depth=40, n_estimators=300; total time=  17.5s
# [CV] END .....................max_depth=40, n_estimators=300; total time=  18.2s
# [CV] END .....................max_depth=40, n_estimators=300; total time=  18.8s
# [CV] END .....................max_depth=40, n_estimators=300; total time=  18.5s
#
# {'max_depth': 40, 'n_estimators': 300}
# {'accuracy': (0.979, 0.015),
#  'f1_macro': (0.979, 0.014),
#  'f1_weighted': (0.979, 0.015),
#  'fit_time': (18.166, 0.483),
#  'precision_macro': (0.981, 0.013),
#  'precision_weighted': (0.98, 0.014),
#  'recall_macro': (0.978, 0.015),
#  'recall_weighted': (0.979, 0.015),
#  'score_time': (0.058, 0.001)}
# Total programs: 800
# Processed 500 snippets...
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END .....................max_depth=40, n_estimators=300; total time=  22.7s
# [CV] END .....................max_depth=40, n_estimators=300; total time=  23.5s
# [CV] END .....................max_depth=40, n_estimators=300; total time=  22.3s
# [CV] END .....................max_depth=40, n_estimators=300; total time=  22.6s
# [CV] END .....................max_depth=40, n_estimators=300; total time=  24.4s
#
# {'max_depth': 40, 'n_estimators': 300}
# {'accuracy': (0.986, 0.011),
#  'f1_macro': (0.987, 0.011),
#  'f1_weighted': (0.986, 0.011),
#  'fit_time': (23.113, 0.755),
#  'precision_macro': (0.988, 0.01),
#  'precision_weighted': (0.987, 0.01),
#  'recall_macro': (0.986, 0.011),
#  'recall_weighted': (0.986, 0.011),
#  'score_time': (0.066, 0.005)}
# Total programs: 900
# Processed 500 snippets...
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END .....................max_depth=40, n_estimators=300; total time=  25.8s
# [CV] END .....................max_depth=40, n_estimators=300; total time=  26.5s
# [CV] END .....................max_depth=40, n_estimators=300; total time=  26.6s
# [CV] END .....................max_depth=40, n_estimators=300; total time=  24.9s
# [CV] END .....................max_depth=40, n_estimators=300; total time=  26.3s
#
# {'max_depth': 40, 'n_estimators': 300}
# {'accuracy': (0.986, 0.008),
#  'f1_macro': (0.986, 0.007),
#  'f1_weighted': (0.986, 0.008),
#  'fit_time': (26.065, 0.62),
#  'precision_macro': (0.987, 0.007),
#  'precision_weighted': (0.986, 0.007),
#  'recall_macro': (0.986, 0.008),
#  'recall_weighted': (0.986, 0.008),
#  'score_time': (0.064, 0.006)}
# Total programs: 1000
# Processed 500 snippets...
# Processed 1000 snippets...
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END .....................max_depth=40, n_estimators=300; total time=  30.4s
# [CV] END .....................max_depth=40, n_estimators=300; total time=  31.1s
# [CV] END .....................max_depth=40, n_estimators=300; total time=  28.9s
# [CV] END .....................max_depth=40, n_estimators=300; total time=  30.6s
# [CV] END .....................max_depth=40, n_estimators=300; total time=  30.6s
#
# {'max_depth': 40, 'n_estimators': 300}
# {'accuracy': (0.982, 0.013),
#  'f1_macro': (0.982, 0.013),
#  'f1_weighted': (0.982, 0.013),
#  'fit_time': (30.364, 0.773),
#  'precision_macro': (0.983, 0.012),
#  'precision_weighted': (0.983, 0.012),
#  'recall_macro': (0.982, 0.013),
#  'recall_weighted': (0.982, 0.013),
#  'score_time': (0.074, 0.005)}
# [{'accuracy': (0.91, 0.058),
#   'f1_macro': (0.871, 0.094),
#   'fit_time': (1.22, 0.089),
#   'precision_macro': (0.882, 0.094),
#   'recall_macro': (0.888, 0.081),
#   'score_time': (0.037, 0.005)},
#  {'accuracy': (0.935, 0.041),
#   'f1_macro': (0.92, 0.055),
#   'fit_time': (3.07, 0.125),
#   'precision_macro': (0.935, 0.059),
#   'recall_macro': (0.922, 0.047),
#   'score_time': (0.038, 0.001)},
#  {'accuracy': (0.953, 0.029),
#   'f1_macro': (0.946, 0.032),
#   'fit_time': (5.063, 0.079),
#   'precision_macro': (0.962, 0.024),
#   'recall_macro': (0.942, 0.034),
#   'score_time': (0.042, 0.001)},
#  {'accuracy': (0.957, 0.044),
#   'f1_macro': (0.955, 0.046),
#   'fit_time': (7.464, 0.156),
#   'precision_macro': (0.965, 0.036),
#   'recall_macro': (0.953, 0.048),
#   'score_time': (0.046, 0.001)},
#  {'accuracy': (0.978, 0.021),
#   'f1_macro': (0.977, 0.024),
#   'fit_time': (10.223, 0.118),
#   'precision_macro': (0.981, 0.019),
#   'recall_macro': (0.976, 0.024),
#   'score_time': (0.049, 0.001)},
#  {'accuracy': (0.977, 0.016),
#   'f1_macro': (0.975, 0.017),
#   'fit_time': (14.574, 0.133),
#   'precision_macro': (0.979, 0.015),
#   'recall_macro': (0.975, 0.017),
#   'score_time': (0.054, 0.001)},
#  {'accuracy': (0.979, 0.015),
#   'f1_macro': (0.979, 0.014),
#   'fit_time': (18.166, 0.483),
#   'precision_macro': (0.981, 0.013),
#   'recall_macro': (0.978, 0.015),
#   'score_time': (0.058, 0.001)},
#  {'accuracy': (0.986, 0.011),
#   'f1_macro': (0.987, 0.011),
#   'fit_time': (23.113, 0.755),
#   'precision_macro': (0.988, 0.01),
#   'recall_macro': (0.986, 0.011),
#   'score_time': (0.066, 0.005)},
#  {'accuracy': (0.986, 0.008),
#   'f1_macro': (0.986, 0.007),
#   'fit_time': (26.065, 0.62),
#   'precision_macro': (0.987, 0.007),
#   'recall_macro': (0.986, 0.008),
#   'score_time': (0.064, 0.006)},
#  {'accuracy': (0.982, 0.013),
#   'f1_macro': (0.982, 0.013),
#   'fit_time': (30.364, 0.773),
#   'precision_macro': (0.983, 0.012),
#   'recall_macro': (0.982, 0.013),
#   'score_time': (0.074, 0.005)}]

# %%
stats = statistics(dataset, MLPClassifier, {
    'activation': ['relu'],
    'learning_rate_init': [0.001]
}, 100, 1000 + 100, 100)
# Out:
# Total programs: 100
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=  22.8s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=  22.9s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=  22.6s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=  21.8s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=  21.1s
#
# {'activation': 'relu', 'learning_rate_init': 0.001}
# {'accuracy': (0.88, 0.081),
#  'f1_macro': (0.812, 0.114),
#  'f1_weighted': (0.858, 0.092),
#  'fit_time': (22.309, 0.684),
#  'precision_macro': (0.816, 0.108),
#  'precision_weighted': (0.868, 0.084),
#  'recall_macro': (0.839, 0.104),
#  'recall_weighted': (0.88, 0.081),
#  'score_time': (0.014, 0.007)}
# Total programs: 200
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=  39.5s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=  37.3s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=  37.1s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=  37.9s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=  38.3s
#
# {'activation': 'relu', 'learning_rate_init': 0.001}
# {'accuracy': (0.94, 0.025),
#  'f1_macro': (0.935, 0.027),
#  'f1_weighted': (0.938, 0.026),
#  'fit_time': (38.089, 0.878),
#  'precision_macro': (0.952, 0.022),
#  'precision_weighted': (0.949, 0.025),
#  'recall_macro': (0.934, 0.029),
#  'recall_weighted': (0.94, 0.025),
#  'score_time': (0.02, 0.004)}
# Total programs: 300
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time= 1.3min
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time= 1.3min
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time= 1.3min
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time= 1.3min
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time= 1.3min
#
# {'activation': 'relu', 'learning_rate_init': 0.001}
# {'accuracy': (0.953, 0.019),
#  'f1_macro': (0.951, 0.02),
#  'f1_weighted': (0.953, 0.019),
#  'fit_time': (76.915, 1.703),
#  'precision_macro': (0.961, 0.018),
#  'precision_weighted': (0.96, 0.017),
#  'recall_macro': (0.95, 0.019),
#  'recall_weighted': (0.953, 0.019),
#  'score_time': (0.021, 0.002)}
# Total programs: 400
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time= 1.4min
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time= 1.4min
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time= 1.4min
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time= 1.4min
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time= 1.4min
#
# {'activation': 'relu', 'learning_rate_init': 0.001}
# {'accuracy': (0.965, 0.012),
#  'f1_macro': (0.965, 0.012),
#  'f1_weighted': (0.965, 0.012),
#  'fit_time': (85.439, 0.74),
#  'precision_macro': (0.97, 0.011),
#  'precision_weighted': (0.97, 0.01),
#  'recall_macro': (0.965, 0.01),
#  'recall_weighted': (0.965, 0.012),
#  'score_time': (0.028, 0.004)}
# Total programs: 500
# Processed 500 snippets...
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time= 1.6min
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time= 1.6min
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time= 1.6min
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time= 1.6min
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time= 1.6min
#
# {'activation': 'relu', 'learning_rate_init': 0.001}
# {'accuracy': (0.97, 0.019),
#  'f1_macro': (0.969, 0.021),
#  'f1_weighted': (0.97, 0.019),
#  'fit_time': (98.002, 0.444),
#  'precision_macro': (0.972, 0.017),
#  'precision_weighted': (0.973, 0.017),
#  'recall_macro': (0.969, 0.022),
#  'recall_weighted': (0.97, 0.019),
#  'score_time': (0.03, 0.001)}
# Total programs: 600
# Processed 500 snippets...
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time= 2.6min
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time= 2.7min
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time= 2.7min
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time= 2.8min
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time= 2.6min
#
# {'activation': 'relu', 'learning_rate_init': 0.001}
# {'accuracy': (0.972, 0.012),
#  'f1_macro': (0.972, 0.012),
#  'f1_weighted': (0.971, 0.013),
#  'fit_time': (159.68, 5.556),
#  'precision_macro': (0.975, 0.01),
#  'precision_weighted': (0.974, 0.011),
#  'recall_macro': (0.972, 0.012),
#  'recall_weighted': (0.972, 0.012),
#  'score_time': (0.035, 0.002)}
# Total programs: 700
# Processed 500 snippets...
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time= 2.5min
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time= 2.7min
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time= 2.6min
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time= 2.6min
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time= 2.6min
#
# {'activation': 'relu', 'learning_rate_init': 0.001}
# {'accuracy': (0.973, 0.024),
#  'f1_macro': (0.973, 0.024),
#  'f1_weighted': (0.973, 0.024),
#  'fit_time': (156.992, 3.954),
#  'precision_macro': (0.975, 0.023),
#  'precision_weighted': (0.975, 0.023),
#  'recall_macro': (0.973, 0.024),
#  'recall_weighted': (0.973, 0.024),
#  'score_time': (0.037, 0.001)}
# Total programs: 800
# Processed 500 snippets...
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time= 3.3min
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time= 3.6min
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time= 3.7min
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time= 3.4min
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time= 3.7min
#
# {'activation': 'relu', 'learning_rate_init': 0.001}
# {'accuracy': (0.971, 0.017),
#  'f1_macro': (0.971, 0.017),
#  'f1_weighted': (0.971, 0.017),
#  'fit_time': (211.999, 9.419),
#  'precision_macro': (0.973, 0.016),
#  'precision_weighted': (0.973, 0.016),
#  'recall_macro': (0.971, 0.017),
#  'recall_weighted': (0.971, 0.017),
#  'score_time': (0.041, 0.001)}
# Total programs: 900
# Processed 500 snippets...
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time= 3.3min
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time= 3.3min
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time= 3.2min
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time= 3.3min
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time= 3.3min
#
# {'activation': 'relu', 'learning_rate_init': 0.001}
# {'accuracy': (0.97, 0.015),
#  'f1_macro': (0.97, 0.015),
#  'f1_weighted': (0.97, 0.015),
#  'fit_time': (196.602, 3.172),
#  'precision_macro': (0.973, 0.014),
#  'precision_weighted': (0.972, 0.014),
#  'recall_macro': (0.97, 0.015),
#  'recall_weighted': (0.97, 0.015),
#  'score_time': (0.048, 0.002)}
# Total programs: 1000
# Processed 500 snippets...
# Processed 1000 snippets...
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time= 3.3min
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time= 3.3min
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time= 3.1min
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time= 3.4min
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time= 3.3min
#
# {'activation': 'relu', 'learning_rate_init': 0.001}
# {'accuracy': (0.975, 0.008),
#  'f1_macro': (0.975, 0.007),
#  'f1_weighted': (0.975, 0.008),
#  'fit_time': (196.758, 6.386),
#  'precision_macro': (0.977, 0.008),
#  'precision_weighted': (0.976, 0.007),
#  'recall_macro': (0.975, 0.007),
#  'recall_weighted': (0.975, 0.008),
#  'score_time': (0.047, 0.003)}
# [{'accuracy': (0.88, 0.081),
#   'f1_macro': (0.812, 0.114),
#   'fit_time': (22.309, 0.684),
#   'precision_macro': (0.816, 0.108),
#   'recall_macro': (0.839, 0.104),
#   'score_time': (0.014, 0.007)},
#  {'accuracy': (0.94, 0.025),
#   'f1_macro': (0.935, 0.027),
#   'fit_time': (38.089, 0.878),
#   'precision_macro': (0.952, 0.022),
#   'recall_macro': (0.934, 0.029),
#   'score_time': (0.02, 0.004)},
#  {'accuracy': (0.953, 0.019),
#   'f1_macro': (0.951, 0.02),
#   'fit_time': (76.915, 1.703),
#   'precision_macro': (0.961, 0.018),
#   'recall_macro': (0.95, 0.019),
#   'score_time': (0.021, 0.002)},
#  {'accuracy': (0.965, 0.012),
#   'f1_macro': (0.965, 0.012),
#   'fit_time': (85.439, 0.74),
#   'precision_macro': (0.97, 0.011),
#   'recall_macro': (0.965, 0.01),
#   'score_time': (0.028, 0.004)},
#  {'accuracy': (0.97, 0.019),
#   'f1_macro': (0.969, 0.021),
#   'fit_time': (98.002, 0.444),
#   'precision_macro': (0.972, 0.017),
#   'recall_macro': (0.969, 0.022),
#   'score_time': (0.03, 0.001)},
#  {'accuracy': (0.972, 0.012),
#   'f1_macro': (0.972, 0.012),
#   'fit_time': (159.68, 5.556),
#   'precision_macro': (0.975, 0.01),
#   'recall_macro': (0.972, 0.012),
#   'score_time': (0.035, 0.002)},
#  {'accuracy': (0.973, 0.024),
#   'f1_macro': (0.973, 0.024),
#   'fit_time': (156.992, 3.954),
#   'precision_macro': (0.975, 0.023),
#   'recall_macro': (0.973, 0.024),
#   'score_time': (0.037, 0.001)},
#  {'accuracy': (0.971, 0.017),
#   'f1_macro': (0.971, 0.017),
#   'fit_time': (211.999, 9.419),
#   'precision_macro': (0.973, 0.016),
#   'recall_macro': (0.971, 0.017),
#   'score_time': (0.041, 0.001)},
#  {'accuracy': (0.97, 0.015),
#   'f1_macro': (0.97, 0.015),
#   'fit_time': (196.602, 3.172),
#   'precision_macro': (0.973, 0.014),
#   'recall_macro': (0.97, 0.015),
#   'score_time': (0.048, 0.002)},
#  {'accuracy': (0.975, 0.008),
#   'f1_macro': (0.975, 0.007),
#   'fit_time': (196.758, 6.386),
#   'precision_macro': (0.977, 0.008),
#   'recall_macro': (0.975, 0.007),
#   'score_time': (0.047, 0.003)}]
