# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import RandomForestClassifier
from utilities import read_dataset_folder, describe, statistics

import random
import numpy as np
import algorithms

import dis
import ast
import pprint
import graphviz
import types

OPS = {
    'jump_backward': lambda i, n: [i.argval],
    'jump_forward': lambda i, n: [i.argval],
    'jump_absolute': lambda i, n: [i.argval],
    'jump_if_not_exc_match': lambda i, n: [i.argval],
    'for_iter': lambda i, n: [i.argval, n.offset],
    'pop_jump_if_true': lambda i, n: [i.argval, n.offset],
    'pop_jump_if_false': lambda i, n: [i.argval, n.offset],
    'pop_jump_if_none': lambda i, n: [i.argval, n.offset],
    'pop_jump_if_not_none': lambda i, n: [i.argval, n.offset],
}

def window(seq, n):
    return [seq[i:i + n] for i in range(len(seq) - n + 1)]

def walk(co, names, edges, init=1):
    no = init
    mask = init * 10000
    bytecode = list(dis.Bytecode(co))
    for i, n in window(bytecode, n=2):
        mi = mask + i.offset
        mn = mask + n.offset
        names[mi] = i.opname
        names[mn] = n.opname
        edges[mi] = []
        opname = i.opname.lower()
        if opname in OPS:
            for offs in OPS[opname](i, n):
                edges[mi].append(mask + offs)
        else:
            edges[mi].append(mn)
        if isinstance(i.argval, types.CodeType):
            no = walk(i.argval, names, edges, no + 1)
    return no

def markov(vertices, edges, type):
    vertypes = set(type(v) for v in vertices if type(v))
    chain_edges = set()
    for vertype in vertypes:
        targets = set(vd for vs in edges for vd in edges[vs] if type(vs) and type(vs) == vertype)
        tartypes = set(type(t) for t in targets if type(t))
        for tartype in tartypes:
            weight = len([t for t in targets if type(t) and type(t) == tartype]) / len(targets)
            chain_edges.add((vertype, tartype, weight))
    return vertypes, chain_edges

def control_flow_graph(src):
    tree = ast.parse(src)
    co = compile(tree, '', 'exec')
    names, edges = {}, {}
    walk(co, names, edges)
    return names, edges

def vectorize(codes):
    chains = []
    nodes = set()
    for code in codes:
        vertices, edges = control_flow_graph(code)
        vertices, edges = markov(vertices.keys(), edges, vertices.get)
        chains.append(edges)
        nodes |= vertices
    nodes = sorted(list(nodes))
    yield nodes
    for edges in chains:
        m = algorithms.adjacency(edges, nodes)
        yield algorithms.vector(m)

def dataset(folder='data', count=2000):
    random.seed(42)
    programs = random.sample(read_dataset_folder(folder), count)
    print(f'Total programs: {len(programs)}')
    vectors = vectorize([code for code, _ in programs])
    h = next(vectors)
    x = np.array(list(vectors), dtype=np.float32)
    y = np.array([klass for _, klass in programs], dtype=int).reshape((len(programs), 1))
    return h, x, y

describe(dataset)
# Out:
# Total programs: 100
# Components: 5329.
# Non-zero components: 33.
# Zero components: 5296.

# %% [markdown]
# **Plots 100-1000**

# %%
stats = statistics(dataset, KNeighborsClassifier, {
    'n_neighbors': [4],
    'weights': ('distance',),
    'metric': ('manhattan',)
}, 100, 1000 + 100, 100)
# Out:
# Total programs: 100
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
#
# {'metric': 'manhattan', 'n_neighbors': 4, 'weights': 'distance'}
# {'accuracy': (0.81, 0.102),
#  'f1_macro': (0.767, 0.092),
#  'f1_weighted': (0.791, 0.096),
#  'fit_time': (0.001, 0.0),
#  'precision_macro': (0.793, 0.079),
#  'precision_weighted': (0.828, 0.071),
#  'recall_macro': (0.793, 0.089),
#  'recall_weighted': (0.81, 0.102),
#  'score_time': (0.009, 0.0)}
# Total programs: 200
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
#
# {'metric': 'manhattan', 'n_neighbors': 4, 'weights': 'distance'}
# {'accuracy': (0.87, 0.048),
#  'f1_macro': (0.849, 0.052),
#  'f1_weighted': (0.863, 0.05),
#  'fit_time': (0.001, 0.0),
#  'precision_macro': (0.877, 0.055),
#  'precision_weighted': (0.889, 0.042),
#  'recall_macro': (0.858, 0.046),
#  'recall_weighted': (0.87, 0.048),
#  'score_time': (0.029, 0.001)}
# Total programs: 300
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.1s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.1s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.1s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.1s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.1s
#
# {'metric': 'manhattan', 'n_neighbors': 4, 'weights': 'distance'}
# {'accuracy': (0.89, 0.008),
#  'f1_macro': (0.875, 0.022),
#  'f1_weighted': (0.884, 0.014),
#  'fit_time': (0.002, 0.0),
#  'precision_macro': (0.895, 0.037),
#  'precision_weighted': (0.9, 0.027),
#  'recall_macro': (0.878, 0.013),
#  'recall_weighted': (0.89, 0.008),
#  'score_time': (0.069, 0.004)}
# Total programs: 400
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.1s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.1s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.1s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.1s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.1s
#
# {'metric': 'manhattan', 'n_neighbors': 4, 'weights': 'distance'}
# {'accuracy': (0.922, 0.037),
#  'f1_macro': (0.912, 0.048),
#  'f1_weighted': (0.918, 0.041),
#  'fit_time': (0.003, 0.0),
#  'precision_macro': (0.936, 0.033),
#  'precision_weighted': (0.933, 0.032),
#  'recall_macro': (0.912, 0.044),
#  'recall_weighted': (0.922, 0.037),
#  'score_time': (0.109, 0.001)}
# Total programs: 500
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.2s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.2s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.2s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.2s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.2s
#
# {'metric': 'manhattan', 'n_neighbors': 4, 'weights': 'distance'}
# {'accuracy': (0.928, 0.023),
#  'f1_macro': (0.923, 0.029),
#  'f1_weighted': (0.926, 0.023),
#  'fit_time': (0.003, 0.0),
#  'precision_macro': (0.94, 0.02),
#  'precision_weighted': (0.937, 0.02),
#  'recall_macro': (0.922, 0.03),
#  'recall_weighted': (0.928, 0.023),
#  'score_time': (0.169, 0.004)}
# Total programs: 600
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.3s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.3s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.3s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.3s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.3s
#
# {'metric': 'manhattan', 'n_neighbors': 4, 'weights': 'distance'}
# {'accuracy': (0.952, 0.017),
#  'f1_macro': (0.951, 0.017),
#  'f1_weighted': (0.952, 0.017),
#  'fit_time': (0.004, 0.0),
#  'precision_macro': (0.958, 0.014),
#  'precision_weighted': (0.958, 0.014),
#  'recall_macro': (0.95, 0.018),
#  'recall_weighted': (0.952, 0.017),
#  'score_time': (0.262, 0.005)}
# Total programs: 700
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.4s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.4s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.4s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.4s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.4s
#
# {'metric': 'manhattan', 'n_neighbors': 4, 'weights': 'distance'}
# {'accuracy': (0.946, 0.025),
#  'f1_macro': (0.946, 0.025),
#  'f1_weighted': (0.946, 0.025),
#  'fit_time': (0.004, 0.0),
#  'precision_macro': (0.95, 0.022),
#  'precision_weighted': (0.95, 0.024),
#  'recall_macro': (0.945, 0.026),
#  'recall_weighted': (0.946, 0.025),
#  'score_time': (0.35, 0.003)}
# Total programs: 800
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.5s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.5s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.5s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.5s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.5s
#
# {'metric': 'manhattan', 'n_neighbors': 4, 'weights': 'distance'}
# {'accuracy': (0.966, 0.014),
#  'f1_macro': (0.967, 0.013),
#  'f1_weighted': (0.966, 0.014),
#  'fit_time': (0.005, 0.0),
#  'precision_macro': (0.97, 0.012),
#  'precision_weighted': (0.969, 0.013),
#  'recall_macro': (0.966, 0.013),
#  'recall_weighted': (0.966, 0.014),
#  'score_time': (0.452, 0.001)}
# Total programs: 900
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.6s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.6s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.6s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.6s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.6s
#
# {'metric': 'manhattan', 'n_neighbors': 4, 'weights': 'distance'}
# {'accuracy': (0.964, 0.006),
#  'f1_macro': (0.964, 0.006),
#  'f1_weighted': (0.965, 0.006),
#  'fit_time': (0.006, 0.0),
#  'precision_macro': (0.967, 0.006),
#  'precision_weighted': (0.967, 0.006),
#  'recall_macro': (0.964, 0.006),
#  'recall_weighted': (0.964, 0.006),
#  'score_time': (0.592, 0.002)}
# Total programs: 1000
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.7s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.7s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.7s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.7s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.7s
#
# {'metric': 'manhattan', 'n_neighbors': 4, 'weights': 'distance'}
# {'accuracy': (0.96, 0.016),
#  'f1_macro': (0.96, 0.016),
#  'f1_weighted': (0.96, 0.016),
#  'fit_time': (0.007, 0.0),
#  'precision_macro': (0.963, 0.016),
#  'precision_weighted': (0.963, 0.016),
#  'recall_macro': (0.959, 0.016),
#  'recall_weighted': (0.96, 0.016),
#  'score_time': (0.727, 0.001)}
# [{'accuracy': (0.81, 0.102), 'f1_macro': (0.767, 0.092), 'fit_time': (0.001, 0.0), 'precision_macro': (0.793, 0.079), 'recall_macro': (0.793, 0.089), 'score_time': (0.009, 0.0)},
#  {'accuracy': (0.87, 0.048), 'f1_macro': (0.849, 0.052), 'fit_time': (0.001, 0.0), 'precision_macro': (0.877, 0.055), 'recall_macro': (0.858, 0.046), 'score_time': (0.029, 0.001)},
#  {'accuracy': (0.89, 0.008), 'f1_macro': (0.875, 0.022), 'fit_time': (0.002, 0.0), 'precision_macro': (0.895, 0.037), 'recall_macro': (0.878, 0.013), 'score_time': (0.069, 0.004)},
#  {'accuracy': (0.922, 0.037), 'f1_macro': (0.912, 0.048), 'fit_time': (0.003, 0.0), 'precision_macro': (0.936, 0.033), 'recall_macro': (0.912, 0.044), 'score_time': (0.109, 0.001)},
#  {'accuracy': (0.928, 0.023), 'f1_macro': (0.923, 0.029), 'fit_time': (0.003, 0.0), 'precision_macro': (0.94, 0.02), 'recall_macro': (0.922, 0.03), 'score_time': (0.169, 0.004)},
#  {'accuracy': (0.952, 0.017), 'f1_macro': (0.951, 0.017), 'fit_time': (0.004, 0.0), 'precision_macro': (0.958, 0.014), 'recall_macro': (0.95, 0.018), 'score_time': (0.262, 0.005)},
#  {'accuracy': (0.946, 0.025), 'f1_macro': (0.946, 0.025), 'fit_time': (0.004, 0.0), 'precision_macro': (0.95, 0.022), 'recall_macro': (0.945, 0.026), 'score_time': (0.35, 0.003)},
#  {'accuracy': (0.966, 0.014), 'f1_macro': (0.967, 0.013), 'fit_time': (0.005, 0.0), 'precision_macro': (0.97, 0.012), 'recall_macro': (0.966, 0.013), 'score_time': (0.452, 0.001)},
#  {'accuracy': (0.964, 0.006), 'f1_macro': (0.964, 0.006), 'fit_time': (0.006, 0.0), 'precision_macro': (0.967, 0.006), 'recall_macro': (0.964, 0.006), 'score_time': (0.592, 0.002)},
#  {'accuracy': (0.96, 0.016), 'f1_macro': (0.96, 0.016), 'fit_time': (0.007, 0.0), 'precision_macro': (0.963, 0.016), 'recall_macro': (0.959, 0.016), 'score_time': (0.727, 0.001)}]

# %%
stats = statistics(dataset, SVC, {
    'C': [30],
    'kernel': ('rbf',),
}, 100, 1000 + 100, 100)
# Out:
# Total programs: 100
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
#
# {'C': 30, 'kernel': 'rbf'}
# {'accuracy': (0.82, 0.051),
#  'f1_macro': (0.745, 0.065),
#  'f1_weighted': (0.783, 0.061),
#  'fit_time': (0.014, 0.0),
#  'precision_macro': (0.738, 0.071),
#  'precision_weighted': (0.783, 0.065),
#  'recall_macro': (0.788, 0.053),
#  'recall_weighted': (0.82, 0.051),
#  'score_time': (0.006, 0.0)}
# Total programs: 200
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ...................................C=30, kernel=rbf; total time=   0.1s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.1s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.1s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.1s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.1s
#
# {'C': 30, 'kernel': 'rbf'}
# {'accuracy': (0.905, 0.029),
#  'f1_macro': (0.89, 0.048),
#  'f1_weighted': (0.899, 0.035),
#  'fit_time': (0.063, 0.001),
#  'precision_macro': (0.905, 0.053),
#  'precision_weighted': (0.908, 0.04),
#  'recall_macro': (0.892, 0.045),
#  'recall_weighted': (0.905, 0.029),
#  'score_time': (0.027, 0.001)}
# Total programs: 300
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ...................................C=30, kernel=rbf; total time=   0.2s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.2s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.2s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.2s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.2s
#
# {'C': 30, 'kernel': 'rbf'}
# {'accuracy': (0.927, 0.017),
#  'f1_macro': (0.912, 0.031),
#  'f1_weighted': (0.922, 0.025),
#  'fit_time': (0.149, 0.002),
#  'precision_macro': (0.928, 0.043),
#  'precision_weighted': (0.932, 0.034),
#  'recall_macro': (0.913, 0.022),
#  'recall_weighted': (0.927, 0.017),
#  'score_time': (0.057, 0.002)}
# Total programs: 400
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ...................................C=30, kernel=rbf; total time=   0.3s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.3s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.3s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.3s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.3s
#
# {'C': 30, 'kernel': 'rbf'}
# {'accuracy': (0.952, 0.041),
#  'f1_macro': (0.946, 0.054),
#  'f1_weighted': (0.949, 0.047),
#  'fit_time': (0.23, 0.002),
#  'precision_macro': (0.959, 0.036),
#  'precision_weighted': (0.957, 0.037),
#  'recall_macro': (0.947, 0.049),
#  'recall_weighted': (0.952, 0.041),
#  'score_time': (0.098, 0.003)}
# Total programs: 500
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ...................................C=30, kernel=rbf; total time=   0.5s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.5s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.5s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.5s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.5s
#
# {'C': 30, 'kernel': 'rbf'}
# {'accuracy': (0.97, 0.013),
#  'f1_macro': (0.967, 0.015),
#  'f1_weighted': (0.97, 0.013),
#  'fit_time': (0.324, 0.002),
#  'precision_macro': (0.973, 0.012),
#  'precision_weighted': (0.973, 0.011),
#  'recall_macro': (0.966, 0.015),
#  'recall_weighted': (0.97, 0.013),
#  'score_time': (0.14, 0.003)}
# Total programs: 600
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ...................................C=30, kernel=rbf; total time=   0.7s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.7s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.7s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.7s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.7s
#
# {'C': 30, 'kernel': 'rbf'}
# {'accuracy': (0.977, 0.014),
#  'f1_macro': (0.977, 0.013),
#  'f1_weighted': (0.977, 0.014),
#  'fit_time': (0.472, 0.012),
#  'precision_macro': (0.98, 0.013),
#  'precision_weighted': (0.979, 0.013),
#  'recall_macro': (0.977, 0.012),
#  'recall_weighted': (0.977, 0.014),
#  'score_time': (0.217, 0.004)}
# Total programs: 700
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ...................................C=30, kernel=rbf; total time=   0.9s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.9s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.9s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.9s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.9s
#
# {'C': 30, 'kernel': 'rbf'}
# {'accuracy': (0.974, 0.012),
#  'f1_macro': (0.975, 0.011),
#  'f1_weighted': (0.974, 0.011),
#  'fit_time': (0.66, 0.014),
#  'precision_macro': (0.977, 0.01),
#  'precision_weighted': (0.976, 0.011),
#  'recall_macro': (0.975, 0.012),
#  'recall_weighted': (0.974, 0.012),
#  'score_time': (0.253, 0.003)}
# Total programs: 800
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ...................................C=30, kernel=rbf; total time=   1.2s
# [CV] END ...................................C=30, kernel=rbf; total time=   1.2s
# [CV] END ...................................C=30, kernel=rbf; total time=   1.2s
# [CV] END ...................................C=30, kernel=rbf; total time=   1.2s
# [CV] END ...................................C=30, kernel=rbf; total time=   1.2s
#
# {'C': 30, 'kernel': 'rbf'}
# {'accuracy': (0.983, 0.011),
#  'f1_macro': (0.983, 0.011),
#  'f1_weighted': (0.982, 0.011),
#  'fit_time': (0.886, 0.014),
#  'precision_macro': (0.985, 0.01),
#  'precision_weighted': (0.984, 0.01),
#  'recall_macro': (0.983, 0.011),
#  'recall_weighted': (0.983, 0.011),
#  'score_time': (0.311, 0.01)}
# Total programs: 900
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ...................................C=30, kernel=rbf; total time=   1.8s
# [CV] END ...................................C=30, kernel=rbf; total time=   1.7s
# [CV] END ...................................C=30, kernel=rbf; total time=   1.8s
# [CV] END ...................................C=30, kernel=rbf; total time=   1.8s
# [CV] END ...................................C=30, kernel=rbf; total time=   1.8s
#
# {'C': 30, 'kernel': 'rbf'}
# {'accuracy': (0.978, 0.006),
#  'f1_macro': (0.978, 0.006),
#  'f1_weighted': (0.978, 0.006),
#  'fit_time': (1.363, 0.015),
#  'precision_macro': (0.98, 0.006),
#  'precision_weighted': (0.979, 0.006),
#  'recall_macro': (0.978, 0.006),
#  'recall_weighted': (0.978, 0.006),
#  'score_time': (0.395, 0.011)}
# Total programs: 1000
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ...................................C=30, kernel=rbf; total time=   2.3s
# [CV] END ...................................C=30, kernel=rbf; total time=   2.2s
# [CV] END ...................................C=30, kernel=rbf; total time=   2.3s
# [CV] END ...................................C=30, kernel=rbf; total time=   2.3s
# [CV] END ...................................C=30, kernel=rbf; total time=   2.3s
#
# {'C': 30, 'kernel': 'rbf'}
# {'accuracy': (0.977, 0.013),
#  'f1_macro': (0.978, 0.012),
#  'f1_weighted': (0.977, 0.013),
#  'fit_time': (1.746, 0.027),
#  'precision_macro': (0.98, 0.012),
#  'precision_weighted': (0.979, 0.012),
#  'recall_macro': (0.977, 0.013),
#  'recall_weighted': (0.977, 0.013),
#  'score_time': (0.516, 0.006)}
# [{'accuracy': (0.82, 0.051), 'f1_macro': (0.745, 0.065), 'fit_time': (0.014, 0.0), 'precision_macro': (0.738, 0.071), 'recall_macro': (0.788, 0.053), 'score_time': (0.006, 0.0)},
#  {'accuracy': (0.905, 0.029), 'f1_macro': (0.89, 0.048), 'fit_time': (0.063, 0.001), 'precision_macro': (0.905, 0.053), 'recall_macro': (0.892, 0.045), 'score_time': (0.027, 0.001)},
#  {'accuracy': (0.927, 0.017), 'f1_macro': (0.912, 0.031), 'fit_time': (0.149, 0.002), 'precision_macro': (0.928, 0.043), 'recall_macro': (0.913, 0.022), 'score_time': (0.057, 0.002)},
#  {'accuracy': (0.952, 0.041), 'f1_macro': (0.946, 0.054), 'fit_time': (0.23, 0.002), 'precision_macro': (0.959, 0.036), 'recall_macro': (0.947, 0.049), 'score_time': (0.098, 0.003)},
#  {'accuracy': (0.97, 0.013), 'f1_macro': (0.967, 0.015), 'fit_time': (0.324, 0.002), 'precision_macro': (0.973, 0.012), 'recall_macro': (0.966, 0.015), 'score_time': (0.14, 0.003)},
#  {'accuracy': (0.977, 0.014), 'f1_macro': (0.977, 0.013), 'fit_time': (0.472, 0.012), 'precision_macro': (0.98, 0.013), 'recall_macro': (0.977, 0.012), 'score_time': (0.217, 0.004)},
#  {'accuracy': (0.974, 0.012), 'f1_macro': (0.975, 0.011), 'fit_time': (0.66, 0.014), 'precision_macro': (0.977, 0.01), 'recall_macro': (0.975, 0.012), 'score_time': (0.253, 0.003)},
#  {'accuracy': (0.983, 0.011), 'f1_macro': (0.983, 0.011), 'fit_time': (0.886, 0.014), 'precision_macro': (0.985, 0.01), 'recall_macro': (0.983, 0.011), 'score_time': (0.311, 0.01)},
#  {'accuracy': (0.978, 0.006), 'f1_macro': (0.978, 0.006), 'fit_time': (1.363, 0.015), 'precision_macro': (0.98, 0.006), 'recall_macro': (0.978, 0.006), 'score_time': (0.395, 0.011)},
#  {'accuracy': (0.977, 0.013), 'f1_macro': (0.978, 0.012), 'fit_time': (1.746, 0.027), 'precision_macro': (0.98, 0.012), 'recall_macro': (0.977, 0.013), 'score_time': (0.516, 0.006)}]

# %%
stats = statistics(dataset, RandomForestClassifier, {
    'n_estimators': [300],
    'max_depth': [40],
}, 100, 1000 + 100, 100)
# Out:
# Total programs: 100
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.2s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.2s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.2s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.2s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.2s
#
# {'max_depth': 40, 'n_estimators': 300}
# {'accuracy': (0.87, 0.075),
#  'f1_macro': (0.816, 0.122),
#  'f1_weighted': (0.848, 0.091),
#  'fit_time': (0.206, 0.003),
#  'precision_macro': (0.831, 0.121),
#  'precision_weighted': (0.868, 0.088),
#  'recall_macro': (0.841, 0.104),
#  'recall_weighted': (0.87, 0.075),
#  'score_time': (0.016, 0.0)}
# Total programs: 200
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.3s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.3s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.3s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.3s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.3s
#
# {'max_depth': 40, 'n_estimators': 300}
# {'accuracy': (0.94, 0.025),
#  'f1_macro': (0.921, 0.041),
#  'f1_weighted': (0.932, 0.031),
#  'fit_time': (0.292, 0.004),
#  'precision_macro': (0.935, 0.045),
#  'precision_weighted': (0.942, 0.034),
#  'recall_macro': (0.928, 0.037),
#  'recall_weighted': (0.94, 0.025),
#  'score_time': (0.016, 0.0)}
# Total programs: 300
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.4s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.4s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.4s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.4s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.4s
#
# {'max_depth': 40, 'n_estimators': 300}
# {'accuracy': (0.957, 0.017),
#  'f1_macro': (0.947, 0.022),
#  'f1_weighted': (0.954, 0.02),
#  'fit_time': (0.373, 0.002),
#  'precision_macro': (0.965, 0.012),
#  'precision_weighted': (0.963, 0.015),
#  'recall_macro': (0.946, 0.02),
#  'recall_weighted': (0.957, 0.017),
#  'score_time': (0.017, 0.0)}
# Total programs: 400
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.5s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.5s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.5s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.5s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.6s
#
# {'max_depth': 40, 'n_estimators': 300}
# {'accuracy': (0.97, 0.036),
#  'f1_macro': (0.966, 0.044),
#  'f1_weighted': (0.968, 0.039),
#  'fit_time': (0.519, 0.016),
#  'precision_macro': (0.973, 0.033),
#  'precision_weighted': (0.973, 0.033),
#  'recall_macro': (0.967, 0.043),
#  'recall_weighted': (0.97, 0.036),
#  'score_time': (0.019, 0.001)}
# Total programs: 500
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.7s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.7s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.7s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.7s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.6s
#
# {'max_depth': 40, 'n_estimators': 300}
# {'accuracy': (0.972, 0.025),
#  'f1_macro': (0.966, 0.032),
#  'f1_weighted': (0.971, 0.026),
#  'fit_time': (0.685, 0.03),
#  'precision_macro': (0.975, 0.022),
#  'precision_weighted': (0.975, 0.022),
#  'recall_macro': (0.964, 0.034),
#  'recall_weighted': (0.972, 0.025),
#  'score_time': (0.02, 0.001)}
# Total programs: 600
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.8s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.8s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.8s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.8s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.8s
#
# {'max_depth': 40, 'n_estimators': 300}
# {'accuracy': (0.975, 0.017),
#  'f1_macro': (0.975, 0.017),
#  'f1_weighted': (0.975, 0.017),
#  'fit_time': (0.766, 0.003),
#  'precision_macro': (0.978, 0.015),
#  'precision_weighted': (0.977, 0.016),
#  'recall_macro': (0.974, 0.018),
#  'recall_weighted': (0.975, 0.017),
#  'score_time': (0.02, 0.0)}
# Total programs: 700
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.9s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.9s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.9s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.9s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.9s
#
# {'max_depth': 40, 'n_estimators': 300}
# {'accuracy': (0.973, 0.016),
#  'f1_macro': (0.973, 0.015),
#  'f1_weighted': (0.973, 0.016),
#  'fit_time': (0.864, 0.006),
#  'precision_macro': (0.975, 0.014),
#  'precision_weighted': (0.975, 0.015),
#  'recall_macro': (0.972, 0.015),
#  'recall_weighted': (0.973, 0.016),
#  'score_time': (0.022, 0.0)}
# Total programs: 800
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END .....................max_depth=40, n_estimators=300; total time=   1.0s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   1.0s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   1.0s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   1.0s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   1.0s
#
# {'max_depth': 40, 'n_estimators': 300}
# {'accuracy': (0.975, 0.007),
#  'f1_macro': (0.975, 0.007),
#  'f1_weighted': (0.975, 0.007),
#  'fit_time': (0.965, 0.005),
#  'precision_macro': (0.977, 0.007),
#  'precision_weighted': (0.976, 0.007),
#  'recall_macro': (0.975, 0.006),
#  'recall_weighted': (0.975, 0.007),
#  'score_time': (0.022, 0.0)}
# Total programs: 900
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END .....................max_depth=40, n_estimators=300; total time=   1.1s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   1.1s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   1.1s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   1.1s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   1.1s
#
# {'max_depth': 40, 'n_estimators': 300}
# {'accuracy': (0.981, 0.008),
#  'f1_macro': (0.982, 0.007),
#  'f1_weighted': (0.981, 0.008),
#  'fit_time': (1.113, 0.007),
#  'precision_macro': (0.983, 0.006),
#  'precision_weighted': (0.983, 0.006),
#  'recall_macro': (0.981, 0.007),
#  'recall_weighted': (0.981, 0.008),
#  'score_time': (0.024, 0.0)}
# Total programs: 1000
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END .....................max_depth=40, n_estimators=300; total time=   1.3s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   1.3s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   1.3s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   1.3s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   1.3s
#
# {'max_depth': 40, 'n_estimators': 300}
# {'accuracy': (0.98, 0.005),
#  'f1_macro': (0.98, 0.005),
#  'f1_weighted': (0.98, 0.005),
#  'fit_time': (1.237, 0.005),
#  'precision_macro': (0.982, 0.005),
#  'precision_weighted': (0.981, 0.005),
#  'recall_macro': (0.98, 0.005),
#  'recall_weighted': (0.98, 0.005),
#  'score_time': (0.024, 0.0)}
# [{'accuracy': (0.87, 0.075), 'f1_macro': (0.816, 0.122), 'fit_time': (0.206, 0.003), 'precision_macro': (0.831, 0.121), 'recall_macro': (0.841, 0.104), 'score_time': (0.016, 0.0)},
#  {'accuracy': (0.94, 0.025), 'f1_macro': (0.921, 0.041), 'fit_time': (0.292, 0.004), 'precision_macro': (0.935, 0.045), 'recall_macro': (0.928, 0.037), 'score_time': (0.016, 0.0)},
#  {'accuracy': (0.957, 0.017), 'f1_macro': (0.947, 0.022), 'fit_time': (0.373, 0.002), 'precision_macro': (0.965, 0.012), 'recall_macro': (0.946, 0.02), 'score_time': (0.017, 0.0)},
#  {'accuracy': (0.97, 0.036), 'f1_macro': (0.966, 0.044), 'fit_time': (0.519, 0.016), 'precision_macro': (0.973, 0.033), 'recall_macro': (0.967, 0.043), 'score_time': (0.019, 0.001)},
#  {'accuracy': (0.972, 0.025), 'f1_macro': (0.966, 0.032), 'fit_time': (0.685, 0.03), 'precision_macro': (0.975, 0.022), 'recall_macro': (0.964, 0.034), 'score_time': (0.02, 0.001)},
#  {'accuracy': (0.975, 0.017), 'f1_macro': (0.975, 0.017), 'fit_time': (0.766, 0.003), 'precision_macro': (0.978, 0.015), 'recall_macro': (0.974, 0.018), 'score_time': (0.02, 0.0)},
#  {'accuracy': (0.973, 0.016), 'f1_macro': (0.973, 0.015), 'fit_time': (0.864, 0.006), 'precision_macro': (0.975, 0.014), 'recall_macro': (0.972, 0.015), 'score_time': (0.022, 0.0)},
#  {'accuracy': (0.975, 0.007), 'f1_macro': (0.975, 0.007), 'fit_time': (0.965, 0.005), 'precision_macro': (0.977, 0.007), 'recall_macro': (0.975, 0.006), 'score_time': (0.022, 0.0)},
#  {'accuracy': (0.981, 0.008), 'f1_macro': (0.982, 0.007), 'fit_time': (1.113, 0.007), 'precision_macro': (0.983, 0.006), 'recall_macro': (0.981, 0.007), 'score_time': (0.024, 0.0)},
#  {'accuracy': (0.98, 0.005), 'f1_macro': (0.98, 0.005), 'fit_time': (1.237, 0.005), 'precision_macro': (0.982, 0.005), 'recall_macro': (0.98, 0.005), 'score_time': (0.024, 0.0)}]

# %%
stats = statistics(dataset, MLPClassifier, {
    'activation': ['relu'],
    'learning_rate_init': [0.001]
}, 100, 1000 + 100, 100)
# Out:
# Total programs: 100
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   1.0s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   1.0s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   1.0s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   1.1s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   1.0s
#
# {'activation': 'relu', 'learning_rate_init': 0.001}
# {'accuracy': (0.86, 0.058),
#  'f1_macro': (0.825, 0.095),
#  'f1_weighted': (0.838, 0.073),
#  'fit_time': (1.033, 0.015),
#  'precision_macro': (0.837, 0.105),
#  'precision_weighted': (0.857, 0.082),
#  'recall_macro': (0.851, 0.078),
#  'recall_weighted': (0.86, 0.058),
#  'score_time': (0.004, 0.0)}
# Total programs: 200
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   1.6s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   1.6s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   1.6s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   1.6s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   1.6s
#
# {'activation': 'relu', 'learning_rate_init': 0.001}
# {'accuracy': (0.935, 0.025),
#  'f1_macro': (0.933, 0.032),
#  'f1_weighted': (0.934, 0.027),
#  'fit_time': (1.584, 0.011),
#  'precision_macro': (0.947, 0.022),
#  'precision_weighted': (0.944, 0.023),
#  'recall_macro': (0.933, 0.033),
#  'recall_weighted': (0.935, 0.025),
#  'score_time': (0.004, 0.0)}
# Total programs: 300
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   2.9s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   2.9s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   3.0s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   2.9s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   3.0s
#
# {'activation': 'relu', 'learning_rate_init': 0.001}
# {'accuracy': (0.95, 0.035),
#  'f1_macro': (0.939, 0.051),
#  'f1_weighted': (0.945, 0.044),
#  'fit_time': (2.927, 0.031),
#  'precision_macro': (0.945, 0.057),
#  'precision_weighted': (0.948, 0.047),
#  'recall_macro': (0.942, 0.04),
#  'recall_weighted': (0.95, 0.035),
#  'score_time': (0.005, 0.0)}
# Total programs: 400
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   3.0s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   3.2s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   3.3s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   3.3s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   3.2s
#
# {'activation': 'relu', 'learning_rate_init': 0.001}
# {'accuracy': (0.975, 0.025),
#  'f1_macro': (0.973, 0.027),
#  'f1_weighted': (0.974, 0.026),
#  'fit_time': (3.196, 0.103),
#  'precision_macro': (0.978, 0.023),
#  'precision_weighted': (0.978, 0.023),
#  'recall_macro': (0.972, 0.027),
#  'recall_weighted': (0.975, 0.025),
#  'score_time': (0.005, 0.0)}
# Total programs: 500
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   3.6s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   3.7s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   3.8s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   3.8s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   3.8s
#
# {'activation': 'relu', 'learning_rate_init': 0.001}
# {'accuracy': (0.974, 0.019),
#  'f1_macro': (0.972, 0.021),
#  'f1_weighted': (0.974, 0.019),
#  'fit_time': (3.727, 0.092),
#  'precision_macro': (0.977, 0.016),
#  'precision_weighted': (0.977, 0.016),
#  'recall_macro': (0.971, 0.023),
#  'recall_weighted': (0.974, 0.019),
#  'score_time': (0.006, 0.0)}
# Total programs: 600
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   4.6s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   4.8s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   4.4s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   4.7s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   4.7s
#
# {'activation': 'relu', 'learning_rate_init': 0.001}
# {'accuracy': (0.978, 0.011),
#  'f1_macro': (0.979, 0.011),
#  'f1_weighted': (0.978, 0.011),
#  'fit_time': (4.611, 0.112),
#  'precision_macro': (0.981, 0.01),
#  'precision_weighted': (0.981, 0.01),
#  'recall_macro': (0.978, 0.011),
#  'recall_weighted': (0.978, 0.011),
#  'score_time': (0.007, 0.0)}
# Total programs: 700
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   4.5s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   4.9s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   4.8s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   4.7s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   4.7s
#
# {'activation': 'relu', 'learning_rate_init': 0.001}
# {'accuracy': (0.979, 0.012),
#  'f1_macro': (0.979, 0.011),
#  'f1_weighted': (0.979, 0.012),
#  'fit_time': (4.724, 0.139),
#  'precision_macro': (0.981, 0.011),
#  'precision_weighted': (0.98, 0.011),
#  'recall_macro': (0.979, 0.011),
#  'recall_weighted': (0.979, 0.012),
#  'score_time': (0.007, 0.0)}
# Total programs: 800
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   5.6s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   6.1s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   5.9s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   6.0s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   6.0s
#
# {'activation': 'relu', 'learning_rate_init': 0.001}
# {'accuracy': (0.99, 0.008),
#  'f1_macro': (0.99, 0.007),
#  'f1_weighted': (0.99, 0.007),
#  'fit_time': (5.928, 0.177),
#  'precision_macro': (0.991, 0.007),
#  'precision_weighted': (0.991, 0.007),
#  'recall_macro': (0.99, 0.007),
#  'recall_weighted': (0.99, 0.008),
#  'score_time': (0.007, 0.0)}
# Total programs: 900
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   5.4s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   6.0s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   5.8s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   6.1s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   5.8s
#
# {'activation': 'relu', 'learning_rate_init': 0.001}
# {'accuracy': (0.989, 0.005),
#  'f1_macro': (0.989, 0.005),
#  'f1_weighted': (0.989, 0.005),
#  'fit_time': (5.81, 0.246),
#  'precision_macro': (0.99, 0.005),
#  'precision_weighted': (0.989, 0.005),
#  'recall_macro': (0.989, 0.005),
#  'recall_weighted': (0.989, 0.005),
#  'score_time': (0.008, 0.0)}
# Total programs: 1000
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   5.4s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   6.1s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   6.0s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   5.9s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   5.9s
#
# {'activation': 'relu', 'learning_rate_init': 0.001}
# {'accuracy': (0.986, 0.005),
#  'f1_macro': (0.986, 0.005),
#  'f1_weighted': (0.986, 0.005),
#  'fit_time': (5.85, 0.258),
#  'precision_macro': (0.987, 0.005),
#  'precision_weighted': (0.987, 0.005),
#  'recall_macro': (0.986, 0.005),
#  'recall_weighted': (0.986, 0.005),
#  'score_time': (0.008, 0.001)}
# [{'accuracy': (0.86, 0.058), 'f1_macro': (0.825, 0.095), 'fit_time': (1.033, 0.015), 'precision_macro': (0.837, 0.105), 'recall_macro': (0.851, 0.078), 'score_time': (0.004, 0.0)},
#  {'accuracy': (0.935, 0.025), 'f1_macro': (0.933, 0.032), 'fit_time': (1.584, 0.011), 'precision_macro': (0.947, 0.022), 'recall_macro': (0.933, 0.033), 'score_time': (0.004, 0.0)},
#  {'accuracy': (0.95, 0.035), 'f1_macro': (0.939, 0.051), 'fit_time': (2.927, 0.031), 'precision_macro': (0.945, 0.057), 'recall_macro': (0.942, 0.04), 'score_time': (0.005, 0.0)},
#  {'accuracy': (0.975, 0.025), 'f1_macro': (0.973, 0.027), 'fit_time': (3.196, 0.103), 'precision_macro': (0.978, 0.023), 'recall_macro': (0.972, 0.027), 'score_time': (0.005, 0.0)},
#  {'accuracy': (0.974, 0.019), 'f1_macro': (0.972, 0.021), 'fit_time': (3.727, 0.092), 'precision_macro': (0.977, 0.016), 'recall_macro': (0.971, 0.023), 'score_time': (0.006, 0.0)},
#  {'accuracy': (0.978, 0.011), 'f1_macro': (0.979, 0.011), 'fit_time': (4.611, 0.112), 'precision_macro': (0.981, 0.01), 'recall_macro': (0.978, 0.011), 'score_time': (0.007, 0.0)},
#  {'accuracy': (0.979, 0.012), 'f1_macro': (0.979, 0.011), 'fit_time': (4.724, 0.139), 'precision_macro': (0.981, 0.011), 'recall_macro': (0.979, 0.011), 'score_time': (0.007, 0.0)},
#  {'accuracy': (0.99, 0.008), 'f1_macro': (0.99, 0.007), 'fit_time': (5.928, 0.177), 'precision_macro': (0.991, 0.007), 'recall_macro': (0.99, 0.007), 'score_time': (0.007, 0.0)},
#  {'accuracy': (0.989, 0.005), 'f1_macro': (0.989, 0.005), 'fit_time': (5.81, 0.246), 'precision_macro': (0.99, 0.005), 'recall_macro': (0.989, 0.005), 'score_time': (0.008, 0.0)},
#  {'accuracy': (0.986, 0.005), 'f1_macro': (0.986, 0.005), 'fit_time': (5.85, 0.258), 'precision_macro': (0.987, 0.005), 'recall_macro': (0.986, 0.005), 'score_time': (0.008, 0.001)}]
