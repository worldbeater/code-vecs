# %%
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import RandomForestClassifier

from pprint import pprint
from warnings import catch_warnings, simplefilter

import random
import algorithms
import numpy as np
import csv
import os

MARKOV_MAPPINGS = {
    "Module": None,
    "keyword": None,
    "Return": "Assign",
    "Attribute": "Name",
}

def rename(names):
    new = ()
    for name in names:
        value = MARKOV_MAPPINGS.get(name, name)
        if value is None:
            return None
        new += (value,)
    return new
        
def read(fname):
    with open(fname, 'r', encoding='utf-8') as file:
        reader = csv.reader(file)
        next(reader)
        for entry, in reader:
            yield entry

def read_folder(folder):
    dataset = []
    files = sorted(file for file in os.listdir(folder) if 'task' in file)
    for i, file in enumerate(files):
        for code in read(f'{folder}/{file}'):
            dataset.append([code, i])
    return dataset

def dataset(as_markov, folder='data', count=2000):
    random.seed(42)
    programs = random.sample(read_folder(folder), count)
    print(f'Total programs: {len(programs)}')
    vectors = algorithms.vectorize((code for code, _ in programs), as_markov)
    h = next(vectors)
    x = np.array(list(vectors), dtype=np.float32)
    y = np.array([klass for _, klass in programs], dtype=int).reshape((len(programs), 1))
    return h, x, y

def score(grid_search, scorers):
    required = ['fit_time', 'score_time']
    output = dict()
    for scorer in [f'test_' + s for s in scorers] + required:
        means = grid_search.cv_results_[f'mean_{scorer}']
        stds = grid_search.cv_results_[f'std_{scorer}']
        mean = np.max(means)
        std = np.mean(stds)
        key = scorer if scorer in required else scorer[5:]
        output[key] = (round(mean, 3), round(std, 3))
    return dict(sorted(output.items()))

def find(x, y, estimator, params, verbose=2):
    keys = ['precision_weighted', 'recall_weighted', 'f1_weighted',
            'precision_macro', 'recall_macro', 'f1_macro',
            'accuracy']
    grid_search = GridSearchCV(
        scoring=dict((key, key) for key in keys),
        estimator=estimator(),
        param_grid=params,
        refit='f1_macro',
        verbose=verbose,
        cv=5)
    with catch_warnings():
        simplefilter('ignore')
        grid_search.fit(x, y)
    print()
    pprint(grid_search.best_params_)
    pprint(score(grid_search, keys))
    return grid_search

def statistics(classifier, parameters, *limits):
    keys, scores = ['accuracy', 'precision_macro', 'recall_macro', 'f1_macro'], []
    for count in range(*limits):
        _, X, Y = dataset(markov_mapper, count=count)
        model = find(X, Y, classifier, parameters)
        scores.append(score(model, keys))
    pprint(scores, width=400)
    return scores

def markov_mapper(vertices, edges):
    return algorithms.markov(vertices, edges, lambda n: rename(vertices[n]))

def describe(dataset):
    H, X, Y = dataset(markov_mapper, count=100)
    print(f'Components: {len(X[0])}.')
    print(f'Non-zero components: {len(np.where(X[0] != 0)[0])}.')
    print(f'Zero components: {len(np.where(X[0] == 0)[0])}.')

describe(dataset)
# Out:
# Total programs: 100
# Dims: 66
# Vectorized 100 chains...
# Components: 4356.
# Non-zero components: 19.
# Zero components: 4337.

# %% [markdown]
# **Plots 100-1000**

# %%
stats = statistics(KNeighborsClassifier, {
    'n_neighbors': [4],
    'weights': ('distance',),
    'metric': ('manhattan',)
}, 100, 1000 + 100, 100)
# Out:
# Total programs: 100
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
#
# {'metric': 'manhattan', 'n_neighbors': 4, 'weights': 'distance'}
# {'accuracy': (0.8, 0.055),
#  'f1_macro': (0.754, 0.051),
#  'f1_weighted': (0.784, 0.071),
#  'fit_time': (0.002, 0.0),
#  'precision_macro': (0.788, 0.053),
#  'precision_weighted': (0.834, 0.072),
#  'recall_macro': (0.782, 0.035),
#  'recall_weighted': (0.8, 0.055),
#  'score_time': (0.048, 0.045)}
# Total programs: 200
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
#
# {'metric': 'manhattan', 'n_neighbors': 4, 'weights': 'distance'}
# {'accuracy': (0.88, 0.048),
#  'f1_macro': (0.882, 0.049),
#  'f1_weighted': (0.883, 0.045),
#  'fit_time': (0.003, 0.001),
#  'precision_macro': (0.902, 0.042),
#  'precision_weighted': (0.91, 0.034),
#  'recall_macro': (0.886, 0.047),
#  'recall_weighted': (0.88, 0.048),
#  'score_time': (0.05, 0.001)}
# Total programs: 300
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
#
# {'metric': 'manhattan', 'n_neighbors': 4, 'weights': 'distance'}
# {'accuracy': (0.933, 0.03),
#  'f1_macro': (0.927, 0.032),
#  'f1_weighted': (0.933, 0.029),
#  'fit_time': (0.005, 0.0),
#  'precision_macro': (0.941, 0.025),
#  'precision_weighted': (0.944, 0.023),
#  'recall_macro': (0.925, 0.034),
#  'recall_weighted': (0.933, 0.03),
#  'score_time': (0.081, 0.001)}
# Total programs: 400
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
#
# {'metric': 'manhattan', 'n_neighbors': 4, 'weights': 'distance'}
# {'accuracy': (0.94, 0.035),
#  'f1_macro': (0.94, 0.036),
#  'f1_weighted': (0.94, 0.035),
#  'fit_time': (0.006, 0.001),
#  'precision_macro': (0.953, 0.025),
#  'precision_weighted': (0.95, 0.025),
#  'recall_macro': (0.936, 0.038),
#  'recall_weighted': (0.94, 0.035),
#  'score_time': (0.113, 0.005)}
# Total programs: 500
# Processed 500 snippets...
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.1s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
#
# {'metric': 'manhattan', 'n_neighbors': 4, 'weights': 'distance'}
# {'accuracy': (0.934, 0.03),
#  'f1_macro': (0.931, 0.03),
#  'f1_weighted': (0.933, 0.03),
#  'fit_time': (0.007, 0.002),
#  'precision_macro': (0.945, 0.024),
#  'precision_weighted': (0.944, 0.024),
#  'recall_macro': (0.928, 0.03),
#  'recall_weighted': (0.934, 0.03),
#  'score_time': (0.133, 0.006)}
# Total programs: 600
# Processed 500 snippets...
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.1s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.1s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.1s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.1s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.1s
#
# {'metric': 'manhattan', 'n_neighbors': 4, 'weights': 'distance'}
# {'accuracy': (0.938, 0.021),
#  'f1_macro': (0.938, 0.022),
#  'f1_weighted': (0.939, 0.021),
#  'fit_time': (0.008, 0.002),
#  'precision_macro': (0.948, 0.016),
#  'precision_weighted': (0.948, 0.017),
#  'recall_macro': (0.937, 0.023),
#  'recall_weighted': (0.938, 0.021),
#  'score_time': (0.157, 0.001)}
# Total programs: 700
# Processed 500 snippets...
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.1s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.1s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.1s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.1s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.1s
#
# {'metric': 'manhattan', 'n_neighbors': 4, 'weights': 'distance'}
# {'accuracy': (0.946, 0.023),
#  'f1_macro': (0.945, 0.023),
#  'f1_weighted': (0.946, 0.023),
#  'fit_time': (0.009, 0.002),
#  'precision_macro': (0.952, 0.02),
#  'precision_weighted': (0.954, 0.02),
#  'recall_macro': (0.945, 0.023),
#  'recall_weighted': (0.946, 0.023),
#  'score_time': (0.197, 0.007)}
# Total programs: 800
# Processed 500 snippets...
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.1s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.1s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.1s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.1s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.1s
#
# {'metric': 'manhattan', 'n_neighbors': 4, 'weights': 'distance'}
# {'accuracy': (0.956, 0.014),
#  'f1_macro': (0.956, 0.014),
#  'f1_weighted': (0.957, 0.014),
#  'fit_time': (0.011, 0.002),
#  'precision_macro': (0.962, 0.013),
#  'precision_weighted': (0.962, 0.013),
#  'recall_macro': (0.956, 0.015),
#  'recall_weighted': (0.956, 0.014),
#  'score_time': (0.221, 0.006)}
# Total programs: 900
# Processed 500 snippets...
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.2s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.2s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.2s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.2s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.2s
#
# {'metric': 'manhattan', 'n_neighbors': 4, 'weights': 'distance'}
# {'accuracy': (0.959, 0.009),
#  'f1_macro': (0.959, 0.01),
#  'f1_weighted': (0.959, 0.009),
#  'fit_time': (0.012, 0.002),
#  'precision_macro': (0.964, 0.01),
#  'precision_weighted': (0.964, 0.009),
#  'recall_macro': (0.959, 0.009),
#  'recall_weighted': (0.959, 0.009),
#  'score_time': (0.247, 0.001)}
# Total programs: 1000
# Processed 500 snippets...
# Processed 1000 snippets...
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.2s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.2s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.2s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.2s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.2s
#
# {'metric': 'manhattan', 'n_neighbors': 4, 'weights': 'distance'}
# {'accuracy': (0.957, 0.019),
#  'f1_macro': (0.957, 0.019),
#  'f1_weighted': (0.957, 0.019),
#  'fit_time': (0.014, 0.003),
#  'precision_macro': (0.962, 0.017),
#  'precision_weighted': (0.962, 0.016),
#  'recall_macro': (0.957, 0.019),
#  'recall_weighted': (0.957, 0.019),
#  'score_time': (0.282, 0.004)}
# [{'accuracy': (0.8, 0.055),
#   'f1_macro': (0.754, 0.051),
#   'fit_time': (0.002, 0.0),
#   'precision_macro': (0.788, 0.053),
#   'recall_macro': (0.782, 0.035),
#   'score_time': (0.048, 0.045)},
#  {'accuracy': (0.88, 0.048),
#   'f1_macro': (0.882, 0.049),
#   'fit_time': (0.003, 0.001),
#   'precision_macro': (0.902, 0.042),
#   'recall_macro': (0.886, 0.047),
#   'score_time': (0.05, 0.001)},
#  {'accuracy': (0.933, 0.03),
#   'f1_macro': (0.927, 0.032),
#   'fit_time': (0.005, 0.0),
#   'precision_macro': (0.941, 0.025),
#   'recall_macro': (0.925, 0.034),
#   'score_time': (0.081, 0.001)},
#  {'accuracy': (0.94, 0.035),
#   'f1_macro': (0.94, 0.036),
#   'fit_time': (0.006, 0.001),
#   'precision_macro': (0.953, 0.025),
#   'recall_macro': (0.936, 0.038),
#   'score_time': (0.113, 0.005)},
#  {'accuracy': (0.934, 0.03),
#   'f1_macro': (0.931, 0.03),
#   'fit_time': (0.007, 0.002),
#   'precision_macro': (0.945, 0.024),
#   'recall_macro': (0.928, 0.03),
#   'score_time': (0.133, 0.006)},
#  {'accuracy': (0.938, 0.021),
#   'f1_macro': (0.938, 0.022),
#   'fit_time': (0.008, 0.002),
#   'precision_macro': (0.948, 0.016),
#   'recall_macro': (0.937, 0.023),
#   'score_time': (0.157, 0.001)},
#  {'accuracy': (0.946, 0.023),
#   'f1_macro': (0.945, 0.023),
#   'fit_time': (0.009, 0.002),
#   'precision_macro': (0.952, 0.02),
#   'recall_macro': (0.945, 0.023),
#   'score_time': (0.197, 0.007)},
#  {'accuracy': (0.956, 0.014),
#   'f1_macro': (0.956, 0.014),
#   'fit_time': (0.011, 0.002),
#   'precision_macro': (0.962, 0.013),
#   'recall_macro': (0.956, 0.015),
#   'score_time': (0.221, 0.006)},
#  {'accuracy': (0.959, 0.009),
#   'f1_macro': (0.959, 0.01),
#   'fit_time': (0.012, 0.002),
#   'precision_macro': (0.964, 0.01),
#   'recall_macro': (0.959, 0.009),
#   'score_time': (0.247, 0.001)},
#  {'accuracy': (0.957, 0.019),
#   'f1_macro': (0.957, 0.019),
#   'fit_time': (0.014, 0.003),
#   'precision_macro': (0.962, 0.017),
#   'recall_macro': (0.957, 0.019),
#   'score_time': (0.282, 0.004)}]

# %%
stats = statistics(SVC, {
    'C': [30],
    'kernel': ('rbf',),
}, 100, 1000 + 100, 100)
# Out:
# Total programs: 100
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
#
# {'C': 30, 'kernel': 'rbf'}
# {'accuracy': (0.84, 0.073),
#  'f1_macro': (0.77, 0.096),
#  'f1_weighted': (0.823, 0.09),
#  'fit_time': (0.017, 0.0),
#  'precision_macro': (0.786, 0.089),
#  'precision_weighted': (0.851, 0.089),
#  'recall_macro': (0.8, 0.08),
#  'recall_weighted': (0.84, 0.073),
#  'score_time': (0.011, 0.0)}
# Total programs: 200
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
#
# {'C': 30, 'kernel': 'rbf'}
# {'accuracy': (0.905, 0.043),
#  'f1_macro': (0.896, 0.042),
#  'f1_weighted': (0.906, 0.04),
#  'fit_time': (0.056, 0.002),
#  'precision_macro': (0.924, 0.036),
#  'precision_weighted': (0.932, 0.033),
#  'recall_macro': (0.895, 0.042),
#  'recall_weighted': (0.905, 0.043),
#  'score_time': (0.025, 0.001)}
# Total programs: 300
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
#
# {'C': 30, 'kernel': 'rbf'}
# {'accuracy': (0.953, 0.019),
#  'f1_macro': (0.949, 0.021),
#  'f1_weighted': (0.953, 0.02),
#  'fit_time': (0.092, 0.001),
#  'precision_macro': (0.961, 0.012),
#  'precision_weighted': (0.963, 0.015),
#  'recall_macro': (0.948, 0.025),
#  'recall_weighted': (0.953, 0.019),
#  'score_time': (0.047, 0.002)}
# Total programs: 400
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ...................................C=30, kernel=rbf; total time=   0.1s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.1s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.1s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.1s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.1s
#
# {'C': 30, 'kernel': 'rbf'}
# {'accuracy': (0.967, 0.027),
#  'f1_macro': (0.967, 0.029),
#  'f1_weighted': (0.968, 0.026),
#  'fit_time': (0.136, 0.002),
#  'precision_macro': (0.974, 0.023),
#  'precision_weighted': (0.974, 0.021),
#  'recall_macro': (0.966, 0.03),
#  'recall_weighted': (0.967, 0.027),
#  'score_time': (0.076, 0.003)}
# Total programs: 500
# Processed 500 snippets...
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ...................................C=30, kernel=rbf; total time=   0.2s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.2s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.2s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.2s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.2s
#
# {'C': 30, 'kernel': 'rbf'}
# {'accuracy': (0.968, 0.018),
#  'f1_macro': (0.968, 0.019),
#  'f1_weighted': (0.968, 0.018),
#  'fit_time': (0.181, 0.002),
#  'precision_macro': (0.973, 0.018),
#  'precision_weighted': (0.972, 0.017),
#  'recall_macro': (0.968, 0.019),
#  'recall_weighted': (0.968, 0.018),
#  'score_time': (0.105, 0.001)}
# Total programs: 600
# Processed 500 snippets...
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ...................................C=30, kernel=rbf; total time=   0.3s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.3s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.3s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.3s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.3s
#
# {'C': 30, 'kernel': 'rbf'}
# {'accuracy': (0.972, 0.011),
#  'f1_macro': (0.971, 0.011),
#  'f1_weighted': (0.972, 0.011),
#  'fit_time': (0.232, 0.003),
#  'precision_macro': (0.975, 0.011),
#  'precision_weighted': (0.975, 0.011),
#  'recall_macro': (0.97, 0.011),
#  'recall_weighted': (0.972, 0.011),
#  'score_time': (0.15, 0.001)}
# Total programs: 700
# Processed 500 snippets...
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ...................................C=30, kernel=rbf; total time=   0.4s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.4s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.4s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.4s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.4s
#
# {'C': 30, 'kernel': 'rbf'}
# {'accuracy': (0.97, 0.012),
#  'f1_macro': (0.97, 0.011),
#  'f1_weighted': (0.97, 0.012),
#  'fit_time': (0.288, 0.003),
#  'precision_macro': (0.973, 0.011),
#  'precision_weighted': (0.973, 0.012),
#  'recall_macro': (0.97, 0.011),
#  'recall_weighted': (0.97, 0.012),
#  'score_time': (0.186, 0.003)}
# Total programs: 800
# Processed 500 snippets...
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ...................................C=30, kernel=rbf; total time=   0.5s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.5s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.5s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.5s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.5s
#
# {'C': 30, 'kernel': 'rbf'}
# {'accuracy': (0.968, 0.013),
#  'f1_macro': (0.967, 0.013),
#  'f1_weighted': (0.968, 0.013),
#  'fit_time': (0.342, 0.007),
#  'precision_macro': (0.971, 0.011),
#  'precision_weighted': (0.971, 0.011),
#  'recall_macro': (0.967, 0.014),
#  'recall_weighted': (0.968, 0.013),
#  'score_time': (0.227, 0.004)}
# Total programs: 900
# Processed 500 snippets...
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ...................................C=30, kernel=rbf; total time=   0.6s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.6s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.6s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.6s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.7s
#
# {'C': 30, 'kernel': 'rbf'}
# {'accuracy': (0.976, 0.003),
#  'f1_macro': (0.976, 0.003),
#  'f1_weighted': (0.976, 0.003),
#  'fit_time': (0.453, 0.004),
#  'precision_macro': (0.978, 0.002),
#  'precision_weighted': (0.978, 0.002),
#  'recall_macro': (0.975, 0.003),
#  'recall_weighted': (0.976, 0.003),
#  'score_time': (0.298, 0.007)}
# Total programs: 1000
# Processed 500 snippets...
# Processed 1000 snippets...
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ...................................C=30, kernel=rbf; total time=   0.8s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.8s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.8s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.8s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.8s
#
# {'C': 30, 'kernel': 'rbf'}
# {'accuracy': (0.967, 0.007),
#  'f1_macro': (0.967, 0.006),
#  'f1_weighted': (0.967, 0.007),
#  'fit_time': (0.551, 0.004),
#  'precision_macro': (0.97, 0.007),
#  'precision_weighted': (0.969, 0.007),
#  'recall_macro': (0.967, 0.006),
#  'recall_weighted': (0.967, 0.007),
#  'score_time': (0.342, 0.006)}
# [{'accuracy': (0.84, 0.073), 'f1_macro': (0.77, 0.096), 'fit_time': (0.017, 0.0), 'precision_macro': (0.786, 0.089), 'recall_macro': (0.8, 0.08), 'score_time': (0.011, 0.0)},
#  {'accuracy': (0.905, 0.043),
#   'f1_macro': (0.896, 0.042),
#   'fit_time': (0.056, 0.002),
#   'precision_macro': (0.924, 0.036),
#   'recall_macro': (0.895, 0.042),
#   'score_time': (0.025, 0.001)},
#  {'accuracy': (0.953, 0.019),
#   'f1_macro': (0.949, 0.021),
#   'fit_time': (0.092, 0.001),
#   'precision_macro': (0.961, 0.012),
#   'recall_macro': (0.948, 0.025),
#   'score_time': (0.047, 0.002)},
#  {'accuracy': (0.967, 0.027),
#   'f1_macro': (0.967, 0.029),
#   'fit_time': (0.136, 0.002),
#   'precision_macro': (0.974, 0.023),
#   'recall_macro': (0.966, 0.03),
#   'score_time': (0.076, 0.003)},
#  {'accuracy': (0.968, 0.018),
#   'f1_macro': (0.968, 0.019),
#   'fit_time': (0.181, 0.002),
#   'precision_macro': (0.973, 0.018),
#   'recall_macro': (0.968, 0.019),
#   'score_time': (0.105, 0.001)},
#  {'accuracy': (0.972, 0.011),
#   'f1_macro': (0.971, 0.011),
#   'fit_time': (0.232, 0.003),
#   'precision_macro': (0.975, 0.011),
#   'recall_macro': (0.97, 0.011),
#   'score_time': (0.15, 0.001)},
#  {'accuracy': (0.97, 0.012),
#   'f1_macro': (0.97, 0.011),
#   'fit_time': (0.288, 0.003),
#   'precision_macro': (0.973, 0.011),
#   'recall_macro': (0.97, 0.011),
#   'score_time': (0.186, 0.003)},
#  {'accuracy': (0.968, 0.013),
#   'f1_macro': (0.967, 0.013),
#   'fit_time': (0.342, 0.007),
#   'precision_macro': (0.971, 0.011),
#   'recall_macro': (0.967, 0.014),
#   'score_time': (0.227, 0.004)},
#  {'accuracy': (0.976, 0.003),
#   'f1_macro': (0.976, 0.003),
#   'fit_time': (0.453, 0.004),
#   'precision_macro': (0.978, 0.002),
#   'recall_macro': (0.975, 0.003),
#   'score_time': (0.298, 0.007)},
#  {'accuracy': (0.967, 0.007),
#   'f1_macro': (0.967, 0.006),
#   'fit_time': (0.551, 0.004),
#   'precision_macro': (0.97, 0.007),
#   'recall_macro': (0.967, 0.006),
#   'score_time': (0.342, 0.006)}]

# %%
stats = statistics(RandomForestClassifier, {
    'n_estimators': [300],
    'max_depth': [40],
}, 100, 1000 + 100, 100)
# Out:
# Total programs: 100
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.4s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.4s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.4s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.4s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.4s
#
# {'max_depth': 40, 'n_estimators': 300}
# {'accuracy': (0.92, 0.04),
#  'f1_macro': (0.878, 0.061),
#  'f1_weighted': (0.903, 0.048),
#  'fit_time': (0.452, 0.016),
#  'precision_macro': (0.882, 0.059),
#  'precision_weighted': (0.91, 0.045),
#  'recall_macro': (0.894, 0.053),
#  'recall_weighted': (0.92, 0.04),
#  'score_time': (0.031, 0.001)}
# Total programs: 200
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.5s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.5s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.5s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.5s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.5s
#
# {'max_depth': 40, 'n_estimators': 300}
# {'accuracy': (0.945, 0.029),
#  'f1_macro': (0.938, 0.028),
#  'f1_weighted': (0.943, 0.029),
#  'fit_time': (0.574, 0.008),
#  'precision_macro': (0.959, 0.022),
#  'precision_weighted': (0.957, 0.024),
#  'recall_macro': (0.936, 0.027),
#  'recall_weighted': (0.945, 0.029),
#  'score_time': (0.032, 0.0)}
# Total programs: 300
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.6s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.6s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.7s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.6s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.7s
#
# {'max_depth': 40, 'n_estimators': 300}
# {'accuracy': (0.953, 0.019),
#  'f1_macro': (0.95, 0.024),
#  'f1_weighted': (0.953, 0.02),
#  'fit_time': (0.698, 0.022),
#  'precision_macro': (0.962, 0.017),
#  'precision_weighted': (0.961, 0.015),
#  'recall_macro': (0.948, 0.025),
#  'recall_weighted': (0.953, 0.019),
#  'score_time': (0.036, 0.001)}
# Total programs: 400
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.8s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.8s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.8s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.8s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.8s
#
# {'max_depth': 40, 'n_estimators': 300}
# {'accuracy': (0.968, 0.023),
#  'f1_macro': (0.967, 0.024),
#  'f1_weighted': (0.967, 0.024),
#  'fit_time': (0.819, 0.003),
#  'precision_macro': (0.974, 0.02),
#  'precision_weighted': (0.973, 0.02),
#  'recall_macro': (0.965, 0.024),
#  'recall_weighted': (0.968, 0.023),
#  'score_time': (0.036, 0.001)}
# Total programs: 500
# Processed 500 snippets...
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.9s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.9s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.9s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.9s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.9s
#
# {'max_depth': 40, 'n_estimators': 300}
# {'accuracy': (0.968, 0.015),
#  'f1_macro': (0.965, 0.018),
#  'f1_weighted': (0.968, 0.015),
#  'fit_time': (0.992, 0.008),
#  'precision_macro': (0.972, 0.014),
#  'precision_weighted': (0.972, 0.013),
#  'recall_macro': (0.964, 0.019),
#  'recall_weighted': (0.968, 0.015),
#  'score_time': (0.038, 0.001)}
# Total programs: 600
# Processed 500 snippets...
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END .....................max_depth=40, n_estimators=300; total time=   1.0s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   1.1s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   1.0s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   1.1s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   1.1s
#
# {'max_depth': 40, 'n_estimators': 300}
# {'accuracy': (0.973, 0.012),
#  'f1_macro': (0.973, 0.012),
#  'f1_weighted': (0.973, 0.012),
#  'fit_time': (1.117, 0.019),
#  'precision_macro': (0.978, 0.011),
#  'precision_weighted': (0.976, 0.011),
#  'recall_macro': (0.973, 0.012),
#  'recall_weighted': (0.973, 0.012),
#  'score_time': (0.039, 0.001)}
# Total programs: 700
# Processed 500 snippets...
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END .....................max_depth=40, n_estimators=300; total time=   1.2s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   1.2s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   1.3s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   1.4s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   1.3s
#
# {'max_depth': 40, 'n_estimators': 300}
# {'accuracy': (0.976, 0.01),
#  'f1_macro': (0.976, 0.009),
#  'f1_weighted': (0.976, 0.01),
#  'fit_time': (1.334, 0.062),
#  'precision_macro': (0.979, 0.009),
#  'precision_weighted': (0.978, 0.009),
#  'recall_macro': (0.975, 0.009),
#  'recall_weighted': (0.976, 0.01),
#  'score_time': (0.044, 0.005)}
# Total programs: 800
# Processed 500 snippets...
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END .....................max_depth=40, n_estimators=300; total time=   1.4s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   1.4s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.0s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   1.4s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   1.4s
#
# {'max_depth': 40, 'n_estimators': 300}
# {'accuracy': (0.98, 0.006),
#  'f1_macro': (0.98, 0.006),
#  'f1_weighted': (0.98, 0.006),
#  'fit_time': (0.898, 1.146),
#  'precision_macro': (0.983, 0.005),
#  'precision_weighted': (0.982, 0.005),
#  'recall_macro': (0.98, 0.007),
#  'recall_weighted': (0.98, 0.006),
#  'score_time': (0.043, 0.001)}
# Total programs: 900
# Processed 500 snippets...
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END .....................max_depth=40, n_estimators=300; total time=   1.6s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   1.7s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   1.7s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   1.7s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   1.8s
#
# {'max_depth': 40, 'n_estimators': 300}
# {'accuracy': (0.982, 0.006),
#  'f1_macro': (0.983, 0.006),
#  'f1_weighted': (0.982, 0.006),
#  'fit_time': (1.74, 0.052),
#  'precision_macro': (0.984, 0.005),
#  'precision_weighted': (0.983, 0.006),
#  'recall_macro': (0.983, 0.006),
#  'recall_weighted': (0.982, 0.006),
#  'score_time': (0.044, 0.001)}
# Total programs: 1000
# Processed 500 snippets...
# Processed 1000 snippets...
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END .....................max_depth=40, n_estimators=300; total time=   2.0s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   2.0s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   2.0s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   1.9s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   1.9s
#
# {'max_depth': 40, 'n_estimators': 300}
# {'accuracy': (0.978, 0.009),
#  'f1_macro': (0.978, 0.009),
#  'f1_weighted': (0.978, 0.009),
#  'fit_time': (2.018, 0.048),
#  'precision_macro': (0.98, 0.008),
#  'precision_weighted': (0.979, 0.008),
#  'recall_macro': (0.978, 0.009),
#  'recall_weighted': (0.978, 0.009),
#  'score_time': (0.049, 0.002)}
# [{'accuracy': (0.92, 0.04),
#   'f1_macro': (0.878, 0.061),
#   'fit_time': (0.452, 0.016),
#   'precision_macro': (0.882, 0.059),
#   'recall_macro': (0.894, 0.053),
#   'score_time': (0.031, 0.001)},
#  {'accuracy': (0.945, 0.029),
#   'f1_macro': (0.938, 0.028),
#   'fit_time': (0.574, 0.008),
#   'precision_macro': (0.959, 0.022),
#   'recall_macro': (0.936, 0.027),
#   'score_time': (0.032, 0.0)},
#  {'accuracy': (0.953, 0.019),
#   'f1_macro': (0.95, 0.024),
#   'fit_time': (0.698, 0.022),
#   'precision_macro': (0.962, 0.017),
#   'recall_macro': (0.948, 0.025),
#   'score_time': (0.036, 0.001)},
#  {'accuracy': (0.968, 0.023),
#   'f1_macro': (0.967, 0.024),
#   'fit_time': (0.819, 0.003),
#   'precision_macro': (0.974, 0.02),
#   'recall_macro': (0.965, 0.024),
#   'score_time': (0.036, 0.001)},
#  {'accuracy': (0.968, 0.015),
#   'f1_macro': (0.965, 0.018),
#   'fit_time': (0.992, 0.008),
#   'precision_macro': (0.972, 0.014),
#   'recall_macro': (0.964, 0.019),
#   'score_time': (0.038, 0.001)},
#  {'accuracy': (0.973, 0.012),
#   'f1_macro': (0.973, 0.012),
#   'fit_time': (1.117, 0.019),
#   'precision_macro': (0.978, 0.011),
#   'recall_macro': (0.973, 0.012),
#   'score_time': (0.039, 0.001)},
#  {'accuracy': (0.976, 0.01),
#   'f1_macro': (0.976, 0.009),
#   'fit_time': (1.334, 0.062),
#   'precision_macro': (0.979, 0.009),
#   'recall_macro': (0.975, 0.009),
#   'score_time': (0.044, 0.005)},
#  {'accuracy': (0.98, 0.006),
#   'f1_macro': (0.98, 0.006),
#   'fit_time': (0.898, 1.146),
#   'precision_macro': (0.983, 0.005),
#   'recall_macro': (0.98, 0.007),
#   'score_time': (0.043, 0.001)},
#  {'accuracy': (0.982, 0.006),
#   'f1_macro': (0.983, 0.006),
#   'fit_time': (1.74, 0.052),
#   'precision_macro': (0.984, 0.005),
#   'recall_macro': (0.983, 0.006),
#   'score_time': (0.044, 0.001)},
#  {'accuracy': (0.978, 0.009),
#   'f1_macro': (0.978, 0.009),
#   'fit_time': (2.018, 0.048),
#   'precision_macro': (0.98, 0.008),
#   'recall_macro': (0.978, 0.009),
#   'score_time': (0.049, 0.002)}]

# %%
stats = statistics(MLPClassifier, {
    'activation': ['relu'],
    'learning_rate_init': [0.001]
}, 100, 1000 + 100, 100)
# Out:
# Total programs: 100
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   2.1s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   2.1s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   2.1s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   2.1s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   2.2s
#
# {'activation': 'relu', 'learning_rate_init': 0.001}
# {'accuracy': (0.86, 0.073),
#  'f1_macro': (0.795, 0.1),
#  'f1_weighted': (0.842, 0.081),
#  'fit_time': (2.236, 0.047),
#  'precision_macro': (0.796, 0.105),
#  'precision_weighted': (0.848, 0.083),
#  'recall_macro': (0.82, 0.091),
#  'recall_weighted': (0.86, 0.073),
#  'score_time': (0.009, 0.001)}
# Total programs: 200
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   3.0s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   3.0s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   3.1s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   3.1s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   3.1s
#
# {'activation': 'relu', 'learning_rate_init': 0.001}
# {'accuracy': (0.93, 0.029),
#  'f1_macro': (0.928, 0.028),
#  'f1_weighted': (0.931, 0.028),
#  'fit_time': (3.179, 0.046),
#  'precision_macro': (0.944, 0.024),
#  'precision_weighted': (0.946, 0.024),
#  'recall_macro': (0.926, 0.03),
#  'recall_weighted': (0.93, 0.029),
#  'score_time': (0.008, 0.001)}
# Total programs: 300
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   5.6s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   5.6s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   5.7s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   5.6s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   5.7s
#
# {'activation': 'relu', 'learning_rate_init': 0.001}
# {'accuracy': (0.95, 0.033),
#  'f1_macro': (0.946, 0.039),
#  'f1_weighted': (0.95, 0.034),
#  'fit_time': (5.74, 0.071),
#  'precision_macro': (0.957, 0.031),
#  'precision_weighted': (0.958, 0.028),
#  'recall_macro': (0.945, 0.039),
#  'recall_weighted': (0.95, 0.033),
#  'score_time': (0.009, 0.003)}
# Total programs: 400
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   5.8s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   5.8s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   5.8s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   5.8s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   5.8s
#
# {'activation': 'relu', 'learning_rate_init': 0.001}
# {'accuracy': (0.965, 0.024),
#  'f1_macro': (0.963, 0.027),
#  'f1_weighted': (0.965, 0.024),
#  'fit_time': (5.89, 0.011),
#  'precision_macro': (0.968, 0.023),
#  'precision_weighted': (0.97, 0.02),
#  'recall_macro': (0.964, 0.027),
#  'recall_weighted': (0.965, 0.024),
#  'score_time': (0.009, 0.001)}
# Total programs: 500
# Processed 500 snippets...
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   6.0s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   6.0s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   6.0s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   6.1s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   6.1s
#
# {'activation': 'relu', 'learning_rate_init': 0.001}
# {'accuracy': (0.976, 0.016),
#  'f1_macro': (0.974, 0.017),
#  'f1_weighted': (0.976, 0.016),
#  'fit_time': (6.148, 0.035),
#  'precision_macro': (0.977, 0.016),
#  'precision_weighted': (0.979, 0.015),
#  'recall_macro': (0.973, 0.017),
#  'recall_weighted': (0.976, 0.016),
#  'score_time': (0.009, 0.001)}
# Total programs: 600
# Processed 500 snippets...
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   9.4s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   9.4s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   9.4s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   9.4s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   9.3s
#
# {'activation': 'relu', 'learning_rate_init': 0.001}
# {'accuracy': (0.967, 0.014),
#  'f1_macro': (0.964, 0.015),
#  'f1_weighted': (0.966, 0.014),
#  'fit_time': (9.489, 0.037),
#  'precision_macro': (0.971, 0.011),
#  'precision_weighted': (0.971, 0.012),
#  'recall_macro': (0.964, 0.016),
#  'recall_weighted': (0.967, 0.014),
#  'score_time': (0.01, 0.002)}
# Total programs: 700
# Processed 500 snippets...
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   9.3s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   9.3s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   9.3s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   9.3s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   9.3s
#
# {'activation': 'relu', 'learning_rate_init': 0.001}
# {'accuracy': (0.979, 0.015),
#  'f1_macro': (0.979, 0.015),
#  'f1_weighted': (0.979, 0.015),
#  'fit_time': (9.396, 0.022),
#  'precision_macro': (0.98, 0.014),
#  'precision_weighted': (0.98, 0.014),
#  'recall_macro': (0.979, 0.015),
#  'recall_weighted': (0.979, 0.015),
#  'score_time': (0.009, 0.0)}
# Total programs: 800
# Processed 500 snippets...
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=  13.7s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=  13.6s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=  13.6s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=  13.6s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=  13.7s
#
# {'activation': 'relu', 'learning_rate_init': 0.001}
# {'accuracy': (0.978, 0.01),
#  'f1_macro': (0.977, 0.011),
#  'f1_weighted': (0.977, 0.01),
#  'fit_time': (13.734, 0.029),
#  'precision_macro': (0.979, 0.009),
#  'precision_weighted': (0.979, 0.009),
#  'recall_macro': (0.977, 0.011),
#  'recall_weighted': (0.978, 0.01),
#  'score_time': (0.01, 0.001)}
# Total programs: 900
# Processed 500 snippets...
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=  13.9s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=  13.9s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=  13.9s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=  13.9s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=  13.9s
#
# {'activation': 'relu', 'learning_rate_init': 0.001}
# {'accuracy': (0.974, 0.007),
#  'f1_macro': (0.974, 0.006),
#  'f1_weighted': (0.975, 0.007),
#  'fit_time': (13.983, 0.027),
#  'precision_macro': (0.976, 0.006),
#  'precision_weighted': (0.977, 0.006),
#  'recall_macro': (0.974, 0.007),
#  'recall_weighted': (0.974, 0.007),
#  'score_time': (0.01, 0.0)}
# Total programs: 1000
# Processed 500 snippets...
# Processed 1000 snippets...
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=  13.9s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=  13.9s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=  13.9s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=  13.9s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=  13.9s
#
# {'activation': 'relu', 'learning_rate_init': 0.001}
# {'accuracy': (0.979, 0.012),
#  'f1_macro': (0.979, 0.012),
#  'f1_weighted': (0.979, 0.012),
#  'fit_time': (13.994, 0.029),
#  'precision_macro': (0.98, 0.012),
#  'precision_weighted': (0.98, 0.012),
#  'recall_macro': (0.979, 0.012),
#  'recall_weighted': (0.979, 0.012),
#  'score_time': (0.009, 0.001)}
# [{'accuracy': (0.86, 0.073),
#   'f1_macro': (0.795, 0.1),
#   'fit_time': (2.236, 0.047),
#   'precision_macro': (0.796, 0.105),
#   'recall_macro': (0.82, 0.091),
#   'score_time': (0.009, 0.001)},
#  {'accuracy': (0.93, 0.029),
#   'f1_macro': (0.928, 0.028),
#   'fit_time': (3.179, 0.046),
#   'precision_macro': (0.944, 0.024),
#   'recall_macro': (0.926, 0.03),
#   'score_time': (0.008, 0.001)},
#  {'accuracy': (0.95, 0.033),
#   'f1_macro': (0.946, 0.039),
#   'fit_time': (5.74, 0.071),
#   'precision_macro': (0.957, 0.031),
#   'recall_macro': (0.945, 0.039),
#   'score_time': (0.009, 0.003)},
#  {'accuracy': (0.965, 0.024),
#   'f1_macro': (0.963, 0.027),
#   'fit_time': (5.89, 0.011),
#   'precision_macro': (0.968, 0.023),
#   'recall_macro': (0.964, 0.027),
#   'score_time': (0.009, 0.001)},
#  {'accuracy': (0.976, 0.016),
#   'f1_macro': (0.974, 0.017),
#   'fit_time': (6.148, 0.035),
#   'precision_macro': (0.977, 0.016),
#   'recall_macro': (0.973, 0.017),
#   'score_time': (0.009, 0.001)},
#  {'accuracy': (0.967, 0.014),
#   'f1_macro': (0.964, 0.015),
#   'fit_time': (9.489, 0.037),
#   'precision_macro': (0.971, 0.011),
#   'recall_macro': (0.964, 0.016),
#   'score_time': (0.01, 0.002)},
#  {'accuracy': (0.979, 0.015),
#   'f1_macro': (0.979, 0.015),
#   'fit_time': (9.396, 0.022),
#   'precision_macro': (0.98, 0.014),
#   'recall_macro': (0.979, 0.015),
#   'score_time': (0.009, 0.0)},
#  {'accuracy': (0.978, 0.01),
#   'f1_macro': (0.977, 0.011),
#   'fit_time': (13.734, 0.029),
#   'precision_macro': (0.979, 0.009),
#   'recall_macro': (0.977, 0.011),
#   'score_time': (0.01, 0.001)},
#  {'accuracy': (0.974, 0.007),
#   'f1_macro': (0.974, 0.006),
#   'fit_time': (13.983, 0.027),
#   'precision_macro': (0.976, 0.006),
#   'recall_macro': (0.974, 0.007),
#   'score_time': (0.01, 0.0)},
#  {'accuracy': (0.979, 0.012),
#   'f1_macro': (0.979, 0.012),
#   'fit_time': (13.994, 0.029),
#   'precision_macro': (0.98, 0.012),
#   'recall_macro': (0.979, 0.012),
#   'score_time': (0.009, 0.001)}]
