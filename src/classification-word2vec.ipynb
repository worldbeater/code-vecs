# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import RandomForestClassifier
from utilities import read_dataset_folder, describe, statistics

import keyword
import string
import random
import numpy as np
import io
import tokenize

from gensim.models import Word2Vec

def tokens(code):
    names = dict()
    sio = io.StringIO(code)
    tokens = []
    for token in tokenize.generate_tokens(sio.readline):
        value = token.string
        if token.type == 1 and value not in keyword.kwlist:
            if value not in names:
                names[value] = ''.join(random.choices(string.ascii_letters, k=5))
            value = names[value]
        tokens.append(value)
    return tokens

def vectorize(snippets: list[str]):
    sentences = [tokens(s) for s in snippets]
    model = Word2Vec(sentences, min_count=1, workers=3)
    sentence_vectors = []
    done = 1
    for sentence in sentences:
        if not done % 500:
            print(f'Processed {done} snippets...')
        done += 1
        word_vectors = []
        for word in sentence:
            if word not in model.wv:
                continue
            word_vectors.append(model.wv[word])
        sentence_vector = np.mean(word_vectors, axis=0)
        sentence_vectors.append(sentence_vector)
    return sentence_vectors

def dataset(folder='data', count=2000):
    random.seed(42)
    programs, labels = zip(*random.sample(read_dataset_folder(folder), count))
    print(f'Total programs: {len(programs)}')
    vectors = vectorize(programs)
    x = np.array(list(vectors), dtype=np.float32)
    y = np.array(labels, dtype=int).reshape((len(labels), 1))
    return None, x, y

describe(dataset)
# Out:
# Total programs: 100
# Components: 100.
# Non-zero components: 100.
# Zero components: 0.

# %% [markdown]
# **Plots 100-1000**

# %%
stats = statistics(dataset, KNeighborsClassifier, {
    'n_neighbors': [4],
    'weights': ('distance',),
    'metric': ('manhattan',)
}, 100, 1000 + 100, 100)
# Out:
# Total programs: 100
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
#
# {'metric': 'manhattan', 'n_neighbors': 4, 'weights': 'distance'}
# {'accuracy': (0.39, 0.107),
#  'f1_macro': (0.318, 0.075),
#  'f1_weighted': (0.333, 0.09),
#  'fit_time': (0.001, 0.0),
#  'precision_macro': (0.303, 0.083),
#  'precision_weighted': (0.317, 0.086),
#  'recall_macro': (0.372, 0.079),
#  'recall_weighted': (0.39, 0.107),
#  'score_time': (0.045, 0.046)}
# Total programs: 200
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
#
# {'metric': 'manhattan', 'n_neighbors': 4, 'weights': 'distance'}
# {'accuracy': (0.695, 0.086),
#  'f1_macro': (0.666, 0.09),
#  'f1_weighted': (0.687, 0.091),
#  'fit_time': (0.001, 0.0),
#  'precision_macro': (0.696, 0.106),
#  'precision_weighted': (0.717, 0.102),
#  'recall_macro': (0.677, 0.086),
#  'recall_weighted': (0.695, 0.086),
#  'score_time': (0.022, 0.0)}
# Total programs: 300
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
#
# {'metric': 'manhattan', 'n_neighbors': 4, 'weights': 'distance'}
# {'accuracy': (0.783, 0.03),
#  'f1_macro': (0.764, 0.034),
#  'f1_weighted': (0.777, 0.028),
#  'fit_time': (0.001, 0.0),
#  'precision_macro': (0.804, 0.037),
#  'precision_weighted': (0.813, 0.034),
#  'recall_macro': (0.768, 0.037),
#  'recall_weighted': (0.783, 0.03),
#  'score_time': (0.022, 0.001)}
# Total programs: 400
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
#
# {'metric': 'manhattan', 'n_neighbors': 4, 'weights': 'distance'}
# {'accuracy': (0.855, 0.049),
#  'f1_macro': (0.846, 0.051),
#  'f1_weighted': (0.854, 0.049),
#  'fit_time': (0.001, 0.0),
#  'precision_macro': (0.877, 0.041),
#  'precision_weighted': (0.881, 0.037),
#  'recall_macro': (0.847, 0.05),
#  'recall_weighted': (0.855, 0.049),
#  'score_time': (0.024, 0.001)}
# Total programs: 500
# Processed 500 snippets...
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
#
# {'metric': 'manhattan', 'n_neighbors': 4, 'weights': 'distance'}
# {'accuracy': (0.876, 0.01),
#  'f1_macro': (0.864, 0.016),
#  'f1_weighted': (0.875, 0.011),
#  'fit_time': (0.001, 0.0),
#  'precision_macro': (0.879, 0.015),
#  'precision_weighted': (0.887, 0.011),
#  'recall_macro': (0.862, 0.016),
#  'recall_weighted': (0.876, 0.01),
#  'score_time': (0.026, 0.001)}
# Total programs: 600
# Processed 500 snippets...
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
#
# {'metric': 'manhattan', 'n_neighbors': 4, 'weights': 'distance'}
# {'accuracy': (0.908, 0.014),
#  'f1_macro': (0.903, 0.016),
#  'f1_weighted': (0.909, 0.014),
#  'fit_time': (0.001, 0.001),
#  'precision_macro': (0.911, 0.018),
#  'precision_weighted': (0.915, 0.015),
#  'recall_macro': (0.901, 0.014),
#  'recall_weighted': (0.908, 0.014),
#  'score_time': (0.026, 0.001)}
# Total programs: 700
# Processed 500 snippets...
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
#
# {'metric': 'manhattan', 'n_neighbors': 4, 'weights': 'distance'}
# {'accuracy': (0.913, 0.026),
#  'f1_macro': (0.909, 0.026),
#  'f1_weighted': (0.913, 0.026),
#  'fit_time': (0.001, 0.001),
#  'precision_macro': (0.917, 0.027),
#  'precision_weighted': (0.92, 0.025),
#  'recall_macro': (0.908, 0.025),
#  'recall_weighted': (0.913, 0.026),
#  'score_time': (0.027, 0.001)}
# Total programs: 800
# Processed 500 snippets...
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
#
# {'metric': 'manhattan', 'n_neighbors': 4, 'weights': 'distance'}
# {'accuracy': (0.912, 0.021),
#  'f1_macro': (0.909, 0.021),
#  'f1_weighted': (0.913, 0.021),
#  'fit_time': (0.001, 0.0),
#  'precision_macro': (0.915, 0.022),
#  'precision_weighted': (0.919, 0.02),
#  'recall_macro': (0.909, 0.02),
#  'recall_weighted': (0.912, 0.021),
#  'score_time': (0.027, 0.001)}
# Total programs: 900
# Processed 500 snippets...
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
#
# {'metric': 'manhattan', 'n_neighbors': 4, 'weights': 'distance'}
# {'accuracy': (0.923, 0.012),
#  'f1_macro': (0.921, 0.012),
#  'f1_weighted': (0.924, 0.012),
#  'fit_time': (0.001, 0.001),
#  'precision_macro': (0.927, 0.012),
#  'precision_weighted': (0.929, 0.011),
#  'recall_macro': (0.921, 0.012),
#  'recall_weighted': (0.923, 0.012),
#  'score_time': (0.028, 0.001)}
# Total programs: 1000
# Processed 500 snippets...
# Processed 1000 snippets...
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
# [CV] END ..metric=manhattan, n_neighbors=4, weights=distance; total time=   0.0s
#
# {'metric': 'manhattan', 'n_neighbors': 4, 'weights': 'distance'}
# {'accuracy': (0.923, 0.031),
#  'f1_macro': (0.922, 0.03),
#  'f1_weighted': (0.923, 0.03),
#  'fit_time': (0.001, 0.0),
#  'precision_macro': (0.926, 0.028),
#  'precision_weighted': (0.927, 0.029),
#  'recall_macro': (0.921, 0.031),
#  'recall_weighted': (0.923, 0.031),
#  'score_time': (0.031, 0.002)}
# [{'accuracy': (0.39, 0.107),
#   'f1_macro': (0.318, 0.075),
#   'fit_time': (0.001, 0.0),
#   'precision_macro': (0.303, 0.083),
#   'recall_macro': (0.372, 0.079),
#   'score_time': (0.045, 0.046)},
#  {'accuracy': (0.695, 0.086),
#   'f1_macro': (0.666, 0.09),
#   'fit_time': (0.001, 0.0),
#   'precision_macro': (0.696, 0.106),
#   'recall_macro': (0.677, 0.086),
#   'score_time': (0.022, 0.0)},
#  {'accuracy': (0.783, 0.03),
#   'f1_macro': (0.764, 0.034),
#   'fit_time': (0.001, 0.0),
#   'precision_macro': (0.804, 0.037),
#   'recall_macro': (0.768, 0.037),
#   'score_time': (0.022, 0.001)},
#  {'accuracy': (0.855, 0.049),
#   'f1_macro': (0.846, 0.051),
#   'fit_time': (0.001, 0.0),
#   'precision_macro': (0.877, 0.041),
#   'recall_macro': (0.847, 0.05),
#   'score_time': (0.024, 0.001)},
#  {'accuracy': (0.876, 0.01),
#   'f1_macro': (0.864, 0.016),
#   'fit_time': (0.001, 0.0),
#   'precision_macro': (0.879, 0.015),
#   'recall_macro': (0.862, 0.016),
#   'score_time': (0.026, 0.001)},
#  {'accuracy': (0.908, 0.014),
#   'f1_macro': (0.903, 0.016),
#   'fit_time': (0.001, 0.001),
#   'precision_macro': (0.911, 0.018),
#   'recall_macro': (0.901, 0.014),
#   'score_time': (0.026, 0.001)},
#  {'accuracy': (0.913, 0.026),
#   'f1_macro': (0.909, 0.026),
#   'fit_time': (0.001, 0.001),
#   'precision_macro': (0.917, 0.027),
#   'recall_macro': (0.908, 0.025),
#   'score_time': (0.027, 0.001)},
#  {'accuracy': (0.912, 0.021),
#   'f1_macro': (0.909, 0.021),
#   'fit_time': (0.001, 0.0),
#   'precision_macro': (0.915, 0.022),
#   'recall_macro': (0.909, 0.02),
#   'score_time': (0.027, 0.001)},
#  {'accuracy': (0.923, 0.012),
#   'f1_macro': (0.921, 0.012),
#   'fit_time': (0.001, 0.001),
#   'precision_macro': (0.927, 0.012),
#   'recall_macro': (0.921, 0.012),
#   'score_time': (0.028, 0.001)},
#  {'accuracy': (0.923, 0.031),
#   'f1_macro': (0.922, 0.03),
#   'fit_time': (0.001, 0.0),
#   'precision_macro': (0.926, 0.028),
#   'recall_macro': (0.921, 0.031),
#   'score_time': (0.031, 0.002)}]

# %%
stats = statistics(dataset, SVC, {
    'C': [30],
    'kernel': ('rbf',),
}, 100, 1000 + 100, 100)
# Out:
# Total programs: 100
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
#
# {'C': 30, 'kernel': 'rbf'}
# {'accuracy': (0.25, 0.032),
#  'f1_macro': (0.134, 0.058),
#  'f1_weighted': (0.141, 0.048),
#  'fit_time': (0.002, 0.0),
#  'precision_macro': (0.117, 0.062),
#  'precision_weighted': (0.118, 0.053),
#  'recall_macro': (0.219, 0.041),
#  'recall_weighted': (0.25, 0.032),
#  'score_time': (0.01, 0.006)}
# Total programs: 200
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
#
# {'C': 30, 'kernel': 'rbf'}
# {'accuracy': (0.475, 0.035),
#  'f1_macro': (0.327, 0.025),
#  'f1_weighted': (0.362, 0.021),
#  'fit_time': (0.004, 0.0),
#  'precision_macro': (0.303, 0.02),
#  'precision_weighted': (0.322, 0.014),
#  'recall_macro': (0.415, 0.04),
#  'recall_weighted': (0.475, 0.035),
#  'score_time': (0.008, 0.001)}
# Total programs: 300
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
#
# {'C': 30, 'kernel': 'rbf'}
# {'accuracy': (0.693, 0.036),
#  'f1_macro': (0.633, 0.041),
#  'f1_weighted': (0.663, 0.039),
#  'fit_time': (0.005, 0.0),
#  'precision_macro': (0.683, 0.072),
#  'precision_weighted': (0.699, 0.062),
#  'recall_macro': (0.657, 0.038),
#  'recall_weighted': (0.693, 0.036),
#  'score_time': (0.01, 0.001)}
# Total programs: 400
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
#
# {'C': 30, 'kernel': 'rbf'}
# {'accuracy': (0.8, 0.022),
#  'f1_macro': (0.768, 0.03),
#  'f1_weighted': (0.794, 0.023),
#  'fit_time': (0.006, 0.0),
#  'precision_macro': (0.818, 0.034),
#  'precision_weighted': (0.831, 0.023),
#  'recall_macro': (0.767, 0.026),
#  'recall_weighted': (0.8, 0.022),
#  'score_time': (0.01, 0.0)}
# Total programs: 500
# Processed 500 snippets...
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
#
# {'C': 30, 'kernel': 'rbf'}
# {'accuracy': (0.824, 0.021),
#  'f1_macro': (0.798, 0.02),
#  'f1_weighted': (0.822, 0.02),
#  'fit_time': (0.006, 0.0),
#  'precision_macro': (0.833, 0.021),
#  'precision_weighted': (0.85, 0.021),
#  'recall_macro': (0.797, 0.023),
#  'recall_weighted': (0.824, 0.021),
#  'score_time': (0.011, 0.001)}
# Total programs: 600
# Processed 500 snippets...
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
#
# {'C': 30, 'kernel': 'rbf'}
# {'accuracy': (0.882, 0.008),
#  'f1_macro': (0.874, 0.008),
#  'f1_weighted': (0.881, 0.007),
#  'fit_time': (0.007, 0.001),
#  'precision_macro': (0.893, 0.01),
#  'precision_weighted': (0.895, 0.009),
#  'recall_macro': (0.871, 0.009),
#  'recall_weighted': (0.882, 0.008),
#  'score_time': (0.012, 0.0)}
# Total programs: 700
# Processed 500 snippets...
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
#
# {'C': 30, 'kernel': 'rbf'}
# {'accuracy': (0.914, 0.023),
#  'f1_macro': (0.911, 0.025),
#  'f1_weighted': (0.915, 0.024),
#  'fit_time': (0.008, 0.0),
#  'precision_macro': (0.924, 0.025),
#  'precision_weighted': (0.925, 0.024),
#  'recall_macro': (0.908, 0.025),
#  'recall_weighted': (0.914, 0.023),
#  'score_time': (0.013, 0.0)}
# Total programs: 800
# Processed 500 snippets...
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
#
# {'C': 30, 'kernel': 'rbf'}
# {'accuracy': (0.922, 0.015),
#  'f1_macro': (0.918, 0.016),
#  'f1_weighted': (0.923, 0.015),
#  'fit_time': (0.01, 0.0),
#  'precision_macro': (0.926, 0.018),
#  'precision_weighted': (0.93, 0.017),
#  'recall_macro': (0.917, 0.014),
#  'recall_weighted': (0.922, 0.015),
#  'score_time': (0.015, 0.0)}
# Total programs: 900
# Processed 500 snippets...
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
#
# {'C': 30, 'kernel': 'rbf'}
# {'accuracy': (0.922, 0.013),
#  'f1_macro': (0.92, 0.014),
#  'f1_weighted': (0.923, 0.013),
#  'fit_time': (0.012, 0.007),
#  'precision_macro': (0.926, 0.017),
#  'precision_weighted': (0.928, 0.015),
#  'recall_macro': (0.919, 0.012),
#  'recall_weighted': (0.922, 0.013),
#  'score_time': (0.023, 0.007)}
# Total programs: 1000
# Processed 500 snippets...
# Processed 1000 snippets...
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
# [CV] END ...................................C=30, kernel=rbf; total time=   0.0s
#
# {'C': 30, 'kernel': 'rbf'}
# {'accuracy': (0.925, 0.023),
#  'f1_macro': (0.923, 0.023),
#  'f1_weighted': (0.925, 0.023),
#  'fit_time': (0.015, 0.003),
#  'precision_macro': (0.927, 0.023),
#  'precision_weighted': (0.928, 0.024),
#  'recall_macro': (0.923, 0.023),
#  'recall_weighted': (0.925, 0.023),
#  'score_time': (0.023, 0.005)}
# [{'accuracy': (0.25, 0.032),
#   'f1_macro': (0.134, 0.058),
#   'fit_time': (0.002, 0.0),
#   'precision_macro': (0.117, 0.062),
#   'recall_macro': (0.219, 0.041),
#   'score_time': (0.01, 0.006)},
#  {'accuracy': (0.475, 0.035),
#   'f1_macro': (0.327, 0.025),
#   'fit_time': (0.004, 0.0),
#   'precision_macro': (0.303, 0.02),
#   'recall_macro': (0.415, 0.04),
#   'score_time': (0.008, 0.001)},
#  {'accuracy': (0.693, 0.036),
#   'f1_macro': (0.633, 0.041),
#   'fit_time': (0.005, 0.0),
#   'precision_macro': (0.683, 0.072),
#   'recall_macro': (0.657, 0.038),
#   'score_time': (0.01, 0.001)},
#  {'accuracy': (0.8, 0.022), 'f1_macro': (0.768, 0.03), 'fit_time': (0.006, 0.0), 'precision_macro': (0.818, 0.034), 'recall_macro': (0.767, 0.026), 'score_time': (0.01, 0.0)},
#  {'accuracy': (0.824, 0.021),
#   'f1_macro': (0.798, 0.02),
#   'fit_time': (0.006, 0.0),
#   'precision_macro': (0.833, 0.021),
#   'recall_macro': (0.797, 0.023),
#   'score_time': (0.011, 0.001)},
#  {'accuracy': (0.882, 0.008),
#   'f1_macro': (0.874, 0.008),
#   'fit_time': (0.007, 0.001),
#   'precision_macro': (0.893, 0.01),
#   'recall_macro': (0.871, 0.009),
#   'score_time': (0.012, 0.0)},
#  {'accuracy': (0.914, 0.023),
#   'f1_macro': (0.911, 0.025),
#   'fit_time': (0.008, 0.0),
#   'precision_macro': (0.924, 0.025),
#   'recall_macro': (0.908, 0.025),
#   'score_time': (0.013, 0.0)},
#  {'accuracy': (0.922, 0.015),
#   'f1_macro': (0.918, 0.016),
#   'fit_time': (0.01, 0.0),
#   'precision_macro': (0.926, 0.018),
#   'recall_macro': (0.917, 0.014),
#   'score_time': (0.015, 0.0)},
#  {'accuracy': (0.922, 0.013),
#   'f1_macro': (0.92, 0.014),
#   'fit_time': (0.012, 0.007),
#   'precision_macro': (0.926, 0.017),
#   'recall_macro': (0.919, 0.012),
#   'score_time': (0.023, 0.007)},
#  {'accuracy': (0.925, 0.023),
#   'f1_macro': (0.923, 0.023),
#   'fit_time': (0.015, 0.003),
#   'precision_macro': (0.927, 0.023),
#   'recall_macro': (0.923, 0.023),
#   'score_time': (0.023, 0.005)}]

# %%
stats = statistics(dataset, RandomForestClassifier, {
    'n_estimators': [300],
    'max_depth': [40],
}, 100, 1000 + 100, 100)
# Out:
# Total programs: 100
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.5s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.5s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.4s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.4s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.4s
#
# {'max_depth': 40, 'n_estimators': 300}
# {'accuracy': (0.65, 0.063),
#  'f1_macro': (0.578, 0.054),
#  'f1_weighted': (0.617, 0.068),
#  'fit_time': (0.516, 0.023),
#  'precision_macro': (0.59, 0.05),
#  'precision_weighted': (0.638, 0.06),
#  'recall_macro': (0.614, 0.054),
#  'recall_weighted': (0.65, 0.063),
#  'score_time': (0.034, 0.004)}
# Total programs: 200
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.6s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.6s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.6s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.6s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.6s
#
# {'max_depth': 40, 'n_estimators': 300}
# {'accuracy': (0.735, 0.037),
#  'f1_macro': (0.696, 0.039),
#  'f1_weighted': (0.714, 0.045),
#  'fit_time': (0.663, 0.008),
#  'precision_macro': (0.716, 0.059),
#  'precision_weighted': (0.733, 0.06),
#  'recall_macro': (0.718, 0.033),
#  'recall_weighted': (0.735, 0.037),
#  'score_time': (0.032, 0.001)}
# Total programs: 300
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.7s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.8s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.8s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.7s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.8s
#
# {'max_depth': 40, 'n_estimators': 300}
# {'accuracy': (0.827, 0.036),
#  'f1_macro': (0.812, 0.043),
#  'f1_weighted': (0.82, 0.038),
#  'fit_time': (0.816, 0.014),
#  'precision_macro': (0.854, 0.033),
#  'precision_weighted': (0.857, 0.035),
#  'recall_macro': (0.819, 0.048),
#  'recall_weighted': (0.827, 0.036),
#  'score_time': (0.035, 0.003)}
# Total programs: 400
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END .....................max_depth=40, n_estimators=300; total time=   1.0s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.9s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.9s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   1.0s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   0.9s
#
# {'max_depth': 40, 'n_estimators': 300}
# {'accuracy': (0.872, 0.043),
#  'f1_macro': (0.864, 0.046),
#  'f1_weighted': (0.873, 0.041),
#  'fit_time': (1.017, 0.05),
#  'precision_macro': (0.879, 0.046),
#  'precision_weighted': (0.888, 0.038),
#  'recall_macro': (0.864, 0.047),
#  'recall_weighted': (0.872, 0.043),
#  'score_time': (0.035, 0.002)}
# Total programs: 500
# Processed 500 snippets...
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END .....................max_depth=40, n_estimators=300; total time=   1.1s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   1.1s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   1.1s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   1.1s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   1.1s
#
# {'max_depth': 40, 'n_estimators': 300}
# {'accuracy': (0.9, 0.033),
#  'f1_macro': (0.888, 0.042),
#  'f1_weighted': (0.9, 0.034),
#  'fit_time': (1.163, 0.007),
#  'precision_macro': (0.899, 0.042),
#  'precision_weighted': (0.908, 0.034),
#  'recall_macro': (0.887, 0.042),
#  'recall_weighted': (0.9, 0.033),
#  'score_time': (0.039, 0.005)}
# Total programs: 600
# Processed 500 snippets...
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END .....................max_depth=40, n_estimators=300; total time=   1.3s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   1.3s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   1.3s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   1.3s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   1.3s
#
# {'max_depth': 40, 'n_estimators': 300}
# {'accuracy': (0.923, 0.01),
#  'f1_macro': (0.919, 0.012),
#  'f1_weighted': (0.923, 0.01),
#  'fit_time': (1.341, 0.019),
#  'precision_macro': (0.928, 0.009),
#  'precision_weighted': (0.93, 0.01),
#  'recall_macro': (0.918, 0.014),
#  'recall_weighted': (0.923, 0.01),
#  'score_time': (0.037, 0.001)}
# Total programs: 700
# Processed 500 snippets...
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END .....................max_depth=40, n_estimators=300; total time=   1.6s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   1.5s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   1.5s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   1.5s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   1.5s
#
# {'max_depth': 40, 'n_estimators': 300}
# {'accuracy': (0.929, 0.026),
#  'f1_macro': (0.925, 0.028),
#  'f1_weighted': (0.929, 0.026),
#  'fit_time': (1.551, 0.075),
#  'precision_macro': (0.93, 0.029),
#  'precision_weighted': (0.933, 0.027),
#  'recall_macro': (0.925, 0.028),
#  'recall_weighted': (0.929, 0.026),
#  'score_time': (0.041, 0.003)}
# Total programs: 800
# Processed 500 snippets...
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END .....................max_depth=40, n_estimators=300; total time=   1.6s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   1.6s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   1.6s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   1.6s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   1.7s
#
# {'max_depth': 40, 'n_estimators': 300}
# {'accuracy': (0.932, 0.022),
#  'f1_macro': (0.93, 0.023),
#  'f1_weighted': (0.932, 0.022),
#  'fit_time': (1.692, 0.044),
#  'precision_macro': (0.934, 0.023),
#  'precision_weighted': (0.937, 0.022),
#  'recall_macro': (0.93, 0.022),
#  'recall_weighted': (0.932, 0.022),
#  'score_time': (0.038, 0.002)}
# Total programs: 900
# Processed 500 snippets...
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END .....................max_depth=40, n_estimators=300; total time=   1.8s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   1.8s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   1.8s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   1.7s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   1.8s
#
# {'max_depth': 40, 'n_estimators': 300}
# {'accuracy': (0.933, 0.012),
#  'f1_macro': (0.932, 0.012),
#  'f1_weighted': (0.934, 0.011),
#  'fit_time': (1.836, 0.014),
#  'precision_macro': (0.935, 0.012),
#  'precision_weighted': (0.937, 0.011),
#  'recall_macro': (0.932, 0.011),
#  'recall_weighted': (0.933, 0.012),
#  'score_time': (0.039, 0.002)}
# Total programs: 1000
# Processed 500 snippets...
# Processed 1000 snippets...
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END .....................max_depth=40, n_estimators=300; total time=   2.0s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   2.0s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   2.2s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   2.0s
# [CV] END .....................max_depth=40, n_estimators=300; total time=   1.9s
#
# {'max_depth': 40, 'n_estimators': 300}
# {'accuracy': (0.936, 0.016),
#  'f1_macro': (0.935, 0.016),
#  'f1_weighted': (0.936, 0.016),
#  'fit_time': (2.083, 0.105),
#  'precision_macro': (0.938, 0.015),
#  'precision_weighted': (0.939, 0.016),
#  'recall_macro': (0.935, 0.016),
#  'recall_weighted': (0.936, 0.016),
#  'score_time': (0.04, 0.001)}
# [{'accuracy': (0.65, 0.063), 'f1_macro': (0.578, 0.054), 'fit_time': (0.516, 0.023), 'precision_macro': (0.59, 0.05), 'recall_macro': (0.614, 0.054), 'score_time': (0.034, 0.004)},
#  {'accuracy': (0.735, 0.037), 'f1_macro': (0.696, 0.039), 'fit_time': (0.663, 0.008), 'precision_macro': (0.716, 0.059), 'recall_macro': (0.718, 0.033), 'score_time': (0.032, 0.001)},
#  {'accuracy': (0.827, 0.036), 'f1_macro': (0.812, 0.043), 'fit_time': (0.816, 0.014), 'precision_macro': (0.854, 0.033), 'recall_macro': (0.819, 0.048), 'score_time': (0.035, 0.003)},
#  {'accuracy': (0.872, 0.043), 'f1_macro': (0.864, 0.046), 'fit_time': (1.017, 0.05), 'precision_macro': (0.879, 0.046), 'recall_macro': (0.864, 0.047), 'score_time': (0.035, 0.002)},
#  {'accuracy': (0.9, 0.033), 'f1_macro': (0.888, 0.042), 'fit_time': (1.163, 0.007), 'precision_macro': (0.899, 0.042), 'recall_macro': (0.887, 0.042), 'score_time': (0.039, 0.005)},
#  {'accuracy': (0.923, 0.01), 'f1_macro': (0.919, 0.012), 'fit_time': (1.341, 0.019), 'precision_macro': (0.928, 0.009), 'recall_macro': (0.918, 0.014), 'score_time': (0.037, 0.001)},
#  {'accuracy': (0.929, 0.026), 'f1_macro': (0.925, 0.028), 'fit_time': (1.551, 0.075), 'precision_macro': (0.93, 0.029), 'recall_macro': (0.925, 0.028), 'score_time': (0.041, 0.003)},
#  {'accuracy': (0.932, 0.022), 'f1_macro': (0.93, 0.023), 'fit_time': (1.692, 0.044), 'precision_macro': (0.934, 0.023), 'recall_macro': (0.93, 0.022), 'score_time': (0.038, 0.002)},
#  {'accuracy': (0.933, 0.012), 'f1_macro': (0.932, 0.012), 'fit_time': (1.836, 0.014), 'precision_macro': (0.935, 0.012), 'recall_macro': (0.932, 0.011), 'score_time': (0.039, 0.002)},
#  {'accuracy': (0.936, 0.016), 'f1_macro': (0.935, 0.016), 'fit_time': (2.083, 0.105), 'precision_macro': (0.938, 0.015), 'recall_macro': (0.935, 0.016), 'score_time': (0.04, 0.001)}]

# %%
stats = statistics(dataset, MLPClassifier, {
    'activation': ['relu'],
    'learning_rate_init': [0.001]
}, 100, 1000 + 100, 100)
# Out:
# Total programs: 100
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   0.1s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   0.1s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   0.1s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   0.0s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   0.1s
#
# {'activation': 'relu', 'learning_rate_init': 0.001}
# {'accuracy': (0.19, 0.073),
#  'f1_macro': (0.068, 0.045),
#  'f1_weighted': (0.083, 0.056),
#  'fit_time': (0.155, 0.056),
#  'precision_macro': (0.051, 0.037),
#  'precision_weighted': (0.061, 0.045),
#  'recall_macro': (0.148, 0.053),
#  'recall_weighted': (0.19, 0.073),
#  'score_time': (0.007, 0.001)}
# Total programs: 200
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   0.0s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   0.1s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   0.1s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   0.1s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   0.1s
#
# {'activation': 'relu', 'learning_rate_init': 0.001}
# {'accuracy': (0.3, 0.096),
#  'f1_macro': (0.144, 0.067),
#  'f1_weighted': (0.18, 0.082),
#  'fit_time': (0.16, 0.069),
#  'precision_macro': (0.112, 0.054),
#  'precision_weighted': (0.139, 0.067),
#  'recall_macro': (0.238, 0.082),
#  'recall_weighted': (0.3, 0.096),
#  'score_time': (0.007, 0.002)}
# Total programs: 300
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   0.3s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   0.3s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   0.3s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   0.3s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   0.3s
#
# {'activation': 'relu', 'learning_rate_init': 0.001}
# {'accuracy': (0.553, 0.027),
#  'f1_macro': (0.446, 0.037),
#  'f1_weighted': (0.489, 0.037),
#  'fit_time': (0.357, 0.001),
#  'precision_macro': (0.433, 0.046),
#  'precision_weighted': (0.476, 0.05),
#  'recall_macro': (0.507, 0.031),
#  'recall_weighted': (0.553, 0.027),
#  'score_time': (0.007, 0.001)}
# Total programs: 400
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   0.3s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   0.3s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   0.3s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   0.3s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   0.3s
#
# {'activation': 'relu', 'learning_rate_init': 0.001}
# {'accuracy': (0.725, 0.037),
#  'f1_macro': (0.693, 0.038),
#  'f1_weighted': (0.715, 0.038),
#  'fit_time': (0.383, 0.001),
#  'precision_macro': (0.756, 0.06),
#  'precision_weighted': (0.76, 0.049),
#  'recall_macro': (0.696, 0.033),
#  'recall_weighted': (0.725, 0.037),
#  'score_time': (0.007, 0.001)}
# Total programs: 500
# Processed 500 snippets...
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   0.3s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   0.3s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   0.3s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   0.3s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   0.3s
#
# {'activation': 'relu', 'learning_rate_init': 0.001}
# {'accuracy': (0.75, 0.035),
#  'f1_macro': (0.716, 0.041),
#  'f1_weighted': (0.74, 0.037),
#  'fit_time': (0.405, 0.004),
#  'precision_macro': (0.773, 0.043),
#  'precision_weighted': (0.782, 0.041),
#  'recall_macro': (0.721, 0.041),
#  'recall_weighted': (0.75, 0.035),
#  'score_time': (0.007, 0.0)}
# Total programs: 600
# Processed 500 snippets...
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   0.5s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   0.5s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   0.5s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   0.5s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   0.5s
#
# {'activation': 'relu', 'learning_rate_init': 0.001}
# {'accuracy': (0.827, 0.003),
#  'f1_macro': (0.818, 0.004),
#  'f1_weighted': (0.826, 0.004),
#  'fit_time': (0.568, 0.002),
#  'precision_macro': (0.833, 0.003),
#  'precision_weighted': (0.84, 0.004),
#  'recall_macro': (0.817, 0.004),
#  'recall_weighted': (0.827, 0.003),
#  'score_time': (0.006, 0.0)}
# Total programs: 700
# Processed 500 snippets...
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   0.5s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   0.5s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   0.5s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   0.5s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   0.5s
#
# {'activation': 'relu', 'learning_rate_init': 0.001}
# {'accuracy': (0.846, 0.023),
#  'f1_macro': (0.829, 0.018),
#  'f1_weighted': (0.84, 0.021),
#  'fit_time': (0.605, 0.01),
#  'precision_macro': (0.856, 0.03),
#  'precision_weighted': (0.861, 0.029),
#  'recall_macro': (0.833, 0.02),
#  'recall_weighted': (0.846, 0.023),
#  'score_time': (0.007, 0.001)}
# Total programs: 800
# Processed 500 snippets...
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   0.8s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   0.7s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   0.7s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   0.7s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   0.7s
#
# {'activation': 'relu', 'learning_rate_init': 0.001}
# {'accuracy': (0.894, 0.023),
#  'f1_macro': (0.889, 0.023),
#  'f1_weighted': (0.895, 0.024),
#  'fit_time': (0.787, 0.032),
#  'precision_macro': (0.898, 0.022),
#  'precision_weighted': (0.903, 0.022),
#  'recall_macro': (0.888, 0.022),
#  'recall_weighted': (0.894, 0.023),
#  'score_time': (0.007, 0.0)}
# Total programs: 900
# Processed 500 snippets...
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   0.7s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   0.7s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   0.7s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   0.7s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   0.7s
#
# {'activation': 'relu', 'learning_rate_init': 0.001}
# {'accuracy': (0.9, 0.016),
#  'f1_macro': (0.895, 0.016),
#  'f1_weighted': (0.9, 0.016),
#  'fit_time': (0.785, 0.003),
#  'precision_macro': (0.903, 0.018),
#  'precision_weighted': (0.906, 0.016),
#  'recall_macro': (0.894, 0.016),
#  'recall_weighted': (0.9, 0.016),
#  'score_time': (0.008, 0.0)}
# Total programs: 1000
# Processed 500 snippets...
# Processed 1000 snippets...
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   0.7s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   0.7s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   0.7s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   0.7s
# [CV] END ..........activation=relu, learning_rate_init=0.001; total time=   0.7s
#
# {'activation': 'relu', 'learning_rate_init': 0.001}
# {'accuracy': (0.91, 0.018),
#  'f1_macro': (0.908, 0.018),
#  'f1_weighted': (0.911, 0.019),
#  'fit_time': (0.823, 0.016),
#  'precision_macro': (0.913, 0.021),
#  'precision_weighted': (0.916, 0.021),
#  'recall_macro': (0.907, 0.018),
#  'recall_weighted': (0.91, 0.018),
#  'score_time': (0.007, 0.0)}
# [{'accuracy': (0.19, 0.073),
#   'f1_macro': (0.068, 0.045),
#   'fit_time': (0.155, 0.056),
#   'precision_macro': (0.051, 0.037),
#   'recall_macro': (0.148, 0.053),
#   'score_time': (0.007, 0.001)},
#  {'accuracy': (0.3, 0.096),
#   'f1_macro': (0.144, 0.067),
#   'fit_time': (0.16, 0.069),
#   'precision_macro': (0.112, 0.054),
#   'recall_macro': (0.238, 0.082),
#   'score_time': (0.007, 0.002)},
#  {'accuracy': (0.553, 0.027),
#   'f1_macro': (0.446, 0.037),
#   'fit_time': (0.357, 0.001),
#   'precision_macro': (0.433, 0.046),
#   'recall_macro': (0.507, 0.031),
#   'score_time': (0.007, 0.001)},
#  {'accuracy': (0.725, 0.037),
#   'f1_macro': (0.693, 0.038),
#   'fit_time': (0.383, 0.001),
#   'precision_macro': (0.756, 0.06),
#   'recall_macro': (0.696, 0.033),
#   'score_time': (0.007, 0.001)},
#  {'accuracy': (0.75, 0.035),
#   'f1_macro': (0.716, 0.041),
#   'fit_time': (0.405, 0.004),
#   'precision_macro': (0.773, 0.043),
#   'recall_macro': (0.721, 0.041),
#   'score_time': (0.007, 0.0)},
#  {'accuracy': (0.827, 0.003),
#   'f1_macro': (0.818, 0.004),
#   'fit_time': (0.568, 0.002),
#   'precision_macro': (0.833, 0.003),
#   'recall_macro': (0.817, 0.004),
#   'score_time': (0.006, 0.0)},
#  {'accuracy': (0.846, 0.023),
#   'f1_macro': (0.829, 0.018),
#   'fit_time': (0.605, 0.01),
#   'precision_macro': (0.856, 0.03),
#   'recall_macro': (0.833, 0.02),
#   'score_time': (0.007, 0.001)},
#  {'accuracy': (0.894, 0.023),
#   'f1_macro': (0.889, 0.023),
#   'fit_time': (0.787, 0.032),
#   'precision_macro': (0.898, 0.022),
#   'recall_macro': (0.888, 0.022),
#   'score_time': (0.007, 0.0)},
#  {'accuracy': (0.9, 0.016),
#   'f1_macro': (0.895, 0.016),
#   'fit_time': (0.785, 0.003),
#   'precision_macro': (0.903, 0.018),
#   'recall_macro': (0.894, 0.016),
#   'score_time': (0.008, 0.0)},
#  {'accuracy': (0.91, 0.018),
#   'f1_macro': (0.908, 0.018),
#   'fit_time': (0.823, 0.016),
#   'precision_macro': (0.913, 0.021),
#   'recall_macro': (0.907, 0.018),
#   'score_time': (0.007, 0.0)}]
